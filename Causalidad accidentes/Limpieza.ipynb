# %% [markdown]
# ## Causalidad accidentes
# A continuación se va a realizar la limpieza de los datos de accidentes gestionados por la Guardia Urbana en la ciudad de Barcelona según causalidad, obtenidos en la web de Open Data BCN

# %% [markdown]
# Importar la herramienta de pandas que permite trabajar sobre los datos

# %%
import pandas as pd
import re
from datetime import date, datetime

# %% [markdown]
# Exportar los csv

# %%
causalidad_accidentes_2015 = pd.read_csv('causalidad15.csv', index_col=False)
causalidad_accidentes_2016 = pd.read_csv('causalidad16.csv', index_col=False)
causalidad_accidentes_2017 = pd.read_csv('causalidad17.csv', index_col=False)
causalidad_accidentes_2017
# Out:
#       Número_d'expedient  Codi_districte        Nom_districte  Codi_barri  \
# 0        2017S009198                  10           Sant Martí          64
# 1        2017S008278                  10           Sant Martí          64
# 2        2017S008462                  10           Sant Martí          64
# 3        2017S001826                  10           Sant Martí          64
# 4        2017S009733                  10           Sant Martí          64
# 5        2017S001624                  10           Sant Martí          64
# 6        2017S005133                  10           Sant Martí          72
# 7        2017S001569                  10           Sant Martí          65
# 8        2017S007531                  10           Sant Martí          65
# 9        2017S010616                  10           Sant Martí          65
# 10       2017S008974                  10           Sant Martí          72
# 11       2017S002287                  10           Sant Martí          65
# 12       2017S003886                  10           Sant Martí          65
# 13       2017S002046                  10           Sant Martí          65
# 14       2017S010357                  10           Sant Martí          65
# 15       2017S001696                  10           Sant Martí          65
# 16       2017S004079                  10           Sant Martí          65
# 17       2017S010563                  10           Sant Martí          65
# 18       2017S006956                  10           Sant Martí          65
# 19       2017S010728                  10           Sant Martí          64
# 20       2017S005517                  10           Sant Martí          73
# 21       2017S009427                  10           Sant Martí          70
# 22       2017S003033                  10           Sant Martí          70
# 23       2017S006954                  10           Sant Martí          73
# 24       2017S003078                  10           Sant Martí          70
# 25       2017S005923                  10           Sant Martí          73
# 26       2017S003328                  10           Sant Martí          72
# 27       2017S010657                  10           Sant Martí          73
# 28       2017S003617                  10           Sant Martí          73
# 29       2017S010006                  10           Sant Martí          71
# ...                  ...             ...                  ...         ...
# 10313    2017S009532                   1         Ciutat Vella           1
# 10314    2017S005753                   1         Ciutat Vella           2
# 10315    2017S007602                   7       Horta-Guinardó          35
# 10316    2017S003772                   4            Les Corts          21
# 10317    2017S007255                   3       Sants-Montjuïc          11
# 10318    2017S007677                   8           Nou Barris          48
# 10319    2017S009782                   9          Sant Andreu          59
# 10320    2017S008100                   8           Nou Barris          53
# 10321    2017S008276                   2             Eixample           8
# 10322    2017S009558                   2             Eixample           7
# 10323    2017S005149                   2             Eixample           7
# 10324    2017S005199                   2             Eixample           5
# 10325    2017S008250                   4            Les Corts          20
# 10326    2017S009402                   2             Eixample           8
# 10327    2017S005236                  10           Sant Martí          65
# 10328    2017S006060                   6               Gràcia          28
# 10329    2017S009990                  10           Sant Martí          64
# 10330    2017S008141                   2             Eixample           7
# 10331    2017S004761                   2             Eixample           8
# 10332    2017S005183                   1         Ciutat Vella           4
# 10333    2017S008336                   2             Eixample           9
# 10334    2017S009048                  10           Sant Martí          72
# 10335    2017S007964                   8           Nou Barris          53
# 10336    2017S008032                   8           Nou Barris          53
# 10337    2017S006761                   6               Gràcia          28
# 10338    2017S004066                   3       Sants-Montjuïc          12
# 10339    2017S009306                   7       Horta-Guinardó          33
# 10340    2017S009755                  10           Sant Martí          71
# 10341    2017S008017                   5  Sarrià-Sant Gervasi          26
# 10342    2017S009181                   6               Gràcia          32
#
#                                    Nom_barri  Codi_carrer  \
# 0                 el Camp de l'Arpa del Clot       346402
# 1                 el Camp de l'Arpa del Clot        95506
# 2                 el Camp de l'Arpa del Clot        90502
# 3                 el Camp de l'Arpa del Clot       268003
# 4                 el Camp de l'Arpa del Clot        18505
# 5                 el Camp de l'Arpa del Clot       109101
# 6                   Sant Martí de Provençals        60807
# 7                                    el Clot       161101
# 8                                    el Clot       169409
# 9                                    el Clot        18505
# 10                  Sant Martí de Provençals         3406
# 11                                   el Clot       113506
# 12                                   el Clot       161101
# 13                                   el Clot       161101
# 14                                   el Clot       222400
# 15                                   el Clot       209900
# 16                                   el Clot       346800
# 17                                   el Clot       350308
# 18                                   el Clot       223209
# 19                el Camp de l'Arpa del Clot       209900
# 20                       la Verneda i la Pau       266405
# 21                     el Besòs i el Maresme       701265
# 22                     el Besòs i el Maresme       701266
# 23                       la Verneda i la Pau        15201
# 24                     el Besòs i el Maresme       165408
# 25                       la Verneda i la Pau        69700
# 26                  Sant Martí de Provençals       342503
# 27                       la Verneda i la Pau       266405
# 28                       la Verneda i la Pau       266405
# 29                   Provençals del Poblenou       143609
# ...                                      ...          ...
# 10313                               el Raval        67307
# 10314                         el Barri Gòtic        34308
# 10315                            el Guinardó       183002
# 10316                              Pedralbes       114509
# 10317                           el Poble-sec       198804
# 10318                           la Guineueta       186601
# 10319                          el Bon Pastor       264308
# 10320                       la Trinitat Nova       260307
# 10321        l'Antiga Esquerra de l'Eixample       350308
# 10322                 la Dreta de l'Eixample       247659
# 10323                 la Dreta de l'Eixample       148307
# 10324                          el Fort Pienc       197302
# 10325             la Maternitat i Sant Ramon       144601
# 10326        l'Antiga Esquerra de l'Eixample       320704
# 10327                                el Clot        18505
# 10328              Vallcarca i els Penitents       352507
# 10329             el Camp de l'Arpa del Clot       226400
# 10330                 la Dreta de l'Eixample        18505
# 10331        l'Antiga Esquerra de l'Eixample       289105
# 10332  Sant Pere, Santa Caterina i la Ribera        79306
# 10333         la Nova Esquerra de l'Eixample       169409
# 10334               Sant Martí de Provençals       128106
# 10335                       la Trinitat Nova       260307
# 10336                       la Trinitat Nova         4409
# 10337              Vallcarca i els Penitents       352507
# 10338             la Marina del Prat Vermell       701266
# 10339                       el Baix Guinardó       169704
# 10340                Provençals del Poblenou       701414
# 10341                 Sant Gervasi - Galvany       144601
# 10342     el Camp d'en Grassot i Gràcia Nova       297001
#
#                      Nom_carrer  \
# 0                      Trinxant
# 1                         Conca
# 2                       Còrsega
# 3                      Provença
# 4                         Aragó
# 5                     Enamorats
# 6                     Cantàbria
# 7                 Independència
# 8               Corts Catalanes
# 9                         Aragó
# 10                  Agricultura
# 11           Escultors Claperós
# 12                Independència
# 13                Independència
# 14                   Democràcia
# 15                    Meridiana
# 16                     Poblenou
# 17                     València
# 18                     Municipi
# 19                    Meridiana
# 20                         Prim
# 21              Litoral (Besòs)
# 22          Litoral (Llobregat)
# 23                      Andrade
# 24                  Jaume Fabre
# 25                   Ca n'Oliva
# 26                      Treball
# 27                         Prim
# 28                         Prim
# 29                    Josep Pla
# ...                         ...
# 10313                     Carme
# 10314                    Rambla
# 10315             Lluís Sagnier
# 10316                    Espasa
# 10317                 Paral·lel
# 10318                 República
# 10319                    Potosí
# 10320              Platja d'Aro
# 10321                  València
# 10322                Pau Claris
# 10323                    Gràcia
# 10324                    Marina
# 10325                  Diagonal
# 10326                    Sarrià
# 10327                     Aragó
# 10328             Vall d'Hebron
# 10329       Las Navas de Tolosa
# 10330                     Aragó
# 10331                  Rosselló
# 10332           Circumval·lació
# 10333           Corts Catalanes
# 10334                    Fluvià
# 10335              Platja d'Aro
# 10336                Aiguablava
# 10337             Vall d'Hebron
# 10338       Litoral (Llobregat)
# 10339             Josep Ciurana
# 10340                      C-31
# 10341                  Diagonal
# 10342  Sant Antoni Maria Claret
#
#                                          Carrer_Original Num_postal   \
# 0      Trinxant / Ruiz de Padrón                     ...   0090 0090
# 1      Conca / Indústria                             ...   0028 0028
# 2      Còrsega                                       ...   0655 0655
# 3      ROSSELLÓ / Dos de Maig                        ...   0573 0573
# 4      Aragó                                         ...   0537 0537
# 5      ENAMORATS                                     ...   0121 0123
# 6      Cantàbria / Guipúscoa                         ...   0029 0029
# 7      INDEPENDÈNCIA / Aragó                         ...   0261 0261
# 8      Glòries Catalanes / Badajoz                   ...   0823 0823
# 9      Aragó                                         ...   0560 0560
# 10     Huelva / Agricultura                          ...   0284 0288
# 11     PL GLÒRIES CATALAN                            ...   0044 0044
# 12     Independència                                 ...   0239 0239
# 13     INDEPENDÈNCIA                                 ...   0243 0243
# 14     Democràcia                                    ...   0001 0003
# 15     VALÈNCIA / Av Meridiana                       ...   0144 0144
# 16     Corts Catalanes / Poblenou                    ...   0183 0183
# 17     València                                      ...   0640 0644
# 18     Municipi                                      ...   0020 0020
# 19     Meridiana / Mallorca                          ...  0151B0151B
# 20     Prim                                          ...  0210B0210B
# 21     Litoral (Besòs)                               ...   000580000
# 22     Litoral (Llobregat)                           ...   000520000
# 23     Andrade                                       ...  0283X0283X
# 24     Prim                                          ...   0001 0001
# 25     Binèfar                                       ...   0066 0066
# 26     Treball / Andrade                             ...   0197 0197
# 27     Prim / Andrade                                ...   0135 0137
# 28     Prim / Santander                              ...   0252 0252
# 29     Josep Pla                                     ...   0159 0161
# ...                                                  ...         ...
# 10313  Carme                                         ...   0089 0089
# 10314  Rambla                                        ...  0026X0026X
# 10315  Varsòvia / Lluís Sagnier                      ...   0009 0009
# 10316  Bisbe Català / Bosch i Gimpera                ...   0001 0001
# 10317  Paral·lel                                     ...   0103 0103
# 10318  Verdum                                        ...  0002B0002B
# 10319  Potosí                                        ...  0014B0014B
# 10320  Meridiana                                     ...  0001X0001X
# 10321  València / Villarroel                         ...   0121 0121
# 10322  Consell de Cent / Pau Claris                  ...   0121 0121
# 10323  Mallorca / Gràcia                             ...   0080 0080
# 10324  Marina                                        ...   0111 0111
# 10325  Diagonal                                      ...   0645 0645
# 10326  Sarrià / Josep Tarradellas                    ...   0018 0018
# 10327  Aragó / Muntanya                              ...   0637 0637
# 10328  Dalt (Llobregat)                              ...   0029 0029
# 10329  Las Navas de Tolosa / Josep Estivill          ...   0321 0321
# 10330  Aragó / Girona                                ...   0319 0319
# 10331  Balmes / Rosselló                             ...   0219 0219
# 10332  Circumval·lació / Wellington                  ...   0025 0025
# 10333  Corts Catalanes                               ...   0521 0521
# 10334  Huelva / Fluvià                               ...   0236 0276
# 10335  Meridiana                                     ...  0001X0001X
# 10336  Aiguablava / Sa Tuna                          ...   0107 0107
# 10337  Vall d'Hebron                                 ...   0017 0017
# 10338  B-10 (Llobregat)                              ...   0020S0000
# 10339  Thous / Josep Ciurana                         ...   0002 0002
# 10340  C-31                                          ...   020660000
# 10341  Diagonal / Calvet                             ...   0598 0598
# 10342  Sant Antoni Maria Claret / Grassot            ...   0035 0035
#
#       Descripció_dia_setmana    ...     Mes_de_any   Nom_mes  Dia_de_mes  \
# 0                    Dimarts    ...             11  Novembre           7
# 1                   Dissabte    ...             10   Octubre           7
# 2                   Dissabte    ...             10   Octubre          14
# 3                    Dilluns    ...              3      Març           6
# 4                     Dijous    ...             11  Novembre          23
# 5                    Dilluns    ...              2    Febrer          27
# 6                    Dilluns    ...              6      Juny          12
# 7                   Dissabte    ...              2    Febrer          25
# 8                    Dilluns    ...              9  Setembre          11
# 9                   Dissabte    ...             12  Desembre          23
# 10                   Dilluns    ...             10   Octubre          30
# 11                  Dimecres    ...              3      Març          22
# 12                   Dimarts    ...              5      Maig           2
# 13                   Dimarts    ...              3      Març          14
# 14                 Divendres    ...             12  Desembre          15
# 15                  Dimecres    ...              3      Març           1
# 16                   Dilluns    ...              5      Maig           8
# 17                    Dijous    ...             12  Desembre          21
# 18                  Diumenge    ...              8     Agost          13
# 19                    Dijous    ...             12  Desembre          28
# 20                 Divendres    ...              6      Juny          23
# 21                   Dimarts    ...             11  Novembre          14
# 22                  Diumenge    ...              4     Abril           2
# 23                  Diumenge    ...              8     Agost          13
# 24                   Dilluns    ...              4     Abril           3
# 25                 Divendres    ...              7    Juliol           7
# 26                  Dimecres    ...              4     Abril          12
# 27                   Dilluns    ...             12  Desembre          25
# 28                  Dissabte    ...              4     Abril          22
# 29                    Dijous    ...             11  Novembre          30
# ...                      ...    ...            ...       ...         ...
# 10313                 Dijous    ...             11  Novembre          16
# 10314                Dilluns    ...              7    Juliol           3
# 10315                 Dijous    ...              9  Setembre          14
# 10316                 Dijous    ...              4     Abril          27
# 10317               Dimecres    ...              8     Agost          30
# 10318               Dissabte    ...              9  Setembre          16
# 10319              Divendres    ...             11  Novembre          24
# 10320               Dissabte    ...              9  Setembre          30
# 10321               Dissabte    ...             10   Octubre           7
# 10322              Divendres    ...             11  Novembre          17
# 10323                Dilluns    ...              6      Juny          12
# 10324                Dimarts    ...              6      Juny          13
# 10325              Divendres    ...             10   Octubre           6
# 10326                Dilluns    ...             11  Novembre          13
# 10327                 Dijous    ...              6      Juny          15
# 10328               Dimecres    ...              7    Juliol          12
# 10329                 Dijous    ...             11  Novembre          30
# 10330                Dimarts    ...             10   Octubre           3
# 10331                Dimarts    ...              5      Maig          30
# 10332                Dilluns    ...              6      Juny          12
# 10333                Dilluns    ...             10   Octubre           9
# 10334                 Dijous    ...             11  Novembre           2
# 10335                Dimarts    ...              9  Setembre          26
# 10336              Divendres    ...              9  Setembre          29
# 10337              Divendres    ...              8     Agost           4
# 10338                Dilluns    ...              5      Maig           8
# 10339              Divendres    ...             11  Novembre          10
# 10340                 Dijous    ...             11  Novembre          23
# 10341                 Dijous    ...              9  Setembre          28
# 10342                Dimarts    ...             11  Novembre           7
#
#        Hora_de_dia Descripció_torn  Descripció_causa_mediata  \
# 0               14           Tarda    No hi ha causa mediata
# 1               12            Matí    No hi ha causa mediata
# 2               13            Matí    No hi ha causa mediata
# 3                4             Nit               Alcoholèmia
# 4                8            Matí    No hi ha causa mediata
# 5               20           Tarda    No hi ha causa mediata
# 6               10            Matí    No hi ha causa mediata
# 7               15           Tarda    No hi ha causa mediata
# 8               17           Tarda    No hi ha causa mediata
# 9               11            Matí    No hi ha causa mediata
# 10              14           Tarda    No hi ha causa mediata
# 11               9            Matí    No hi ha causa mediata
# 12              15           Tarda    No hi ha causa mediata
# 13              10            Matí    No hi ha causa mediata
# 14               9            Matí    No hi ha causa mediata
# 15              16           Tarda    No hi ha causa mediata
# 16              16           Tarda    No hi ha causa mediata
# 17              15           Tarda    No hi ha causa mediata
# 18              10            Matí    No hi ha causa mediata
# 19              17           Tarda    No hi ha causa mediata
# 20              22             Nit    No hi ha causa mediata
# 21               6            Matí    No hi ha causa mediata
# 22              13            Matí    No hi ha causa mediata
# 23               7            Matí    No hi ha causa mediata
# 24              19           Tarda    No hi ha causa mediata
# 25              11            Matí    No hi ha causa mediata
# 26               9            Matí    No hi ha causa mediata
# 27              23             Nit    No hi ha causa mediata
# 28              20           Tarda    No hi ha causa mediata
# 29              17           Tarda    No hi ha causa mediata
# ...            ...             ...                       ...
# 10313           20           Tarda    No hi ha causa mediata
# 10314            1             Nit    No hi ha causa mediata
# 10315           11            Matí    No hi ha causa mediata
# 10316           23             Nit    No hi ha causa mediata
# 10317           14           Tarda    No hi ha causa mediata
# 10318           20           Tarda    No hi ha causa mediata
# 10319           13            Matí    No hi ha causa mediata
# 10320           21           Tarda    No hi ha causa mediata
# 10321            9            Matí    No hi ha causa mediata
# 10322           14           Tarda    No hi ha causa mediata
# 10323           17           Tarda    No hi ha causa mediata
# 10324           20           Tarda    No hi ha causa mediata
# 10325           14           Tarda    No hi ha causa mediata
# 10326           11            Matí    No hi ha causa mediata
# 10327           10            Matí    No hi ha causa mediata
# 10328            8            Matí    No hi ha causa mediata
# 10329           13            Matí    No hi ha causa mediata
# 10330            8            Matí    No hi ha causa mediata
# 10331           16           Tarda    No hi ha causa mediata
# 10332           19           Tarda    No hi ha causa mediata
# 10333           20           Tarda    No hi ha causa mediata
# 10334           12            Matí    No hi ha causa mediata
# 10335           18           Tarda    No hi ha causa mediata
# 10336           10            Matí    No hi ha causa mediata
# 10337           12            Matí    No hi ha causa mediata
# 10338           13            Matí    No hi ha causa mediata
# 10339           11            Matí    No hi ha causa mediata
# 10340           19           Tarda    No hi ha causa mediata
# 10341           20           Tarda    No hi ha causa mediata
# 10342            9            Matí    No hi ha causa mediata
#
#        Coordenada_UTM_(X) Coordenada_UTM_(Y)  Longitud    Latitud
# 0               431940,75         4585401,48  2.184483  41.415436
# 1               431576,37         4585215,20  2.180149  41.413730
# 2               431384,99         4584870,55  2.177891  41.410606
# 3               431703,06         4584790,47  2.181716  41.409913
# 4               431877,03         4584413,10  2.183841  41.406532
# 5               431890,19         4584524,82  2.183984  41.407533
# 6               433330,95         4585862,62  2.201063  41.419705
# 7               431960,88         4584412,80  2.184834  41.406530
# 8               432229,70         4584197,87  2.188076  41.404617
# 9               431964,93         4584467,51  2.184875  41.407026
# 10              433169,99         4585881,12  2.199134  41.419863
# 11              432296,02         4584356,47  2.188859  41.406054
# 12              432036,77         4584333,52  2.185752  41.405825
# 13              432002,91         4584366,13  2.185341  41.406119
# 14              432656,47         4584684,32  2.193130  41.409039
# 15              432159,75         4584770,81  2.187174  41.409771
# 16              432568,12         4584553,24  2.192091  41.407851
# 17              432266,66         4584952,81  2.188434  41.411420
# 18              432441,43         4584724,20  2.190553  41.409381
# 19              432102,65         4585012,86  2.186465  41.411946
# 20              433578,16         4586258,88  2.203987  41.423292
# 21              434882,87         4584464,92  2.219784  41.407241
# 22              435119,93         4585013,26  2.222560  41.412205
# 23              434036,66         4586097,36  2.209485  41.421880
# 24              434651,99         4585174,61  2.216944  41.413617
# 25              433552,26         4586444,30  2.203655  41.424965
# 26              433345,89         4585479,23  2.201285  41.416257
# 27              433807,00         4585935,39  2.206763  41.420402
# 28              433325,06         4586516,86  2.200931  41.425595
# 29              433865,07         4585330,14  2.207523  41.414958
# ...                   ...                ...       ...        ...
# 10313           430450,62         4581505,97  2.167104  41.380218
# 10314           431200,42         4581288,21  2.176097  41.378329
# 10315           431302,92         4586352,76  2.176741  41.423947
# 10316           426061,02         4583346,26  2.114395  41.396408
# 10317           430089,25         4580906,78  2.162856  41.374792
# 10318           431100,80         4587925,90  2.174145  41.438097
# 10319           433441,34         4588442,21  2.202107  41.442951
# 10320           432262,03         4589091,17  2.187922  41.448698
# 10321           429421,09         4582197,80  2.154718  41.386361
# 10322           430465,81         4582876,92  2.167126  41.392568
# 10323           430137,13         4583034,48  2.163184  41.393963
# 10324           432020,49         4583188,19  2.185689  41.395511
# 10325           426268,48         4582116,12  2.117021  41.385349
# 10326           428532,71         4582671,86  2.144030  41.390552
# 10327           432310,20         4584849,17  2.188972  41.410496
# 10328           428080,25         4585665,76  2.138268  41.417477
# 10329           432013,01         4585497,44  2.185346  41.416307
# 10330           430697,45         4583267,95  2.169856  41.396110
# 10331           429621,91         4582954,99  2.157022  41.393197
# 10332           432566,71         4582245,40  2.192325  41.387064
# 10333           429697,48         4581720,28  2.158074  41.382089
# 10334           432790,02         4585510,13  2.194641  41.416489
# 10335           432262,03         4589091,17  2.187922  41.448698
# 10336           432133,29         4589464,61  2.186336  41.452047
# 10337           428001,49         4585565,29  2.137335  41.416570
# 10338           431031,12         4580394,22  2.174178  41.370262
# 10339           430506,63         4585246,60  2.167344  41.413917
# 10340           432719,59         4584620,76  2.193890  41.408468
# 10341           428683,30         4582975,39  2.145801  41.393303
# 10342           430355,83         4584235,76  2.165653  41.404798
#
# [10343 rows x 23 columns]

# %% [markdown]
# Inspeccionar los tipos de datos de cada tabla y la cantidad de filas y columnas

# %%
causalidad_accidentes_2015.dtypes
# Out:
# Número d expedient          object
# Codi districte               int64
# Nom districte               object
# Codi barri                   int64
# Nom barri                   object
# Codi carrer                  int64
# Nom carrer                  object
# Num postal caption          object
# Descripció dia setmana      object
# Dia setmana                 object
# Descripció tipus dia        object
# NK Any                       int64
# Mes de any                   int64
# Nom mes                     object
# Dia de mes                   int64
# Hora de dia                  int64
# Descripció torn             object
# Descripció causa mediata    object
# Coordenada UTM (Y)          object
# Coordenada UTM (X)          object
# dtype: object

# %%
causalidad_accidentes_2015.shape
# Out:
# (10020, 20)

# %%
causalidad_accidentes_2016.dtypes
# Out:
# Número d'expedient           object
# Codi districte                int64
# Nom districte                object
# Codi barri                    int64
# Nom barri                    object
# Codi carrer                   int64
# Nom carrer                   object
# Num postal caption           object
# Descripció dia setmana       object
# Dia setmana                  object
# Descripció tipus dia         object
# NK Any                        int64
# Mes de any                    int64
# Nom mes                      object
# Dia de mes                    int64
# Hora de dia                   int64
# Descripció torn              object
# Descripció causa mediata     object
# Coordenada UTM (X)           object
# Coordenada UTM (Y)           object
# Long                        float64
# Lat                         float64
# dtype: object

# %%
causalidad_accidentes_2016.shape
# Out:
# (10157, 22)

# %%
causalidad_accidentes_2017.dtypes
# Out:
# Número_d'expedient           object
# Codi_districte                int64
# Nom_districte                object
# Codi_barri                    int64
# Nom_barri                    object
# Codi_carrer                   int64
# Nom_carrer                   object
# Carrer_Original              object
# Num_postal                   object
# Descripció_dia_setmana       object
# Dia_setmana                  object
# Descripció_tipus_dia         object
# NK Any                        int64
# Mes_de_any                    int64
# Nom_mes                      object
# Dia_de_mes                    int64
# Hora_de_dia                   int64
# Descripció_torn              object
# Descripció_causa_mediata     object
# Coordenada_UTM_(X)           object
# Coordenada_UTM_(Y)           object
# Longitud                    float64
# Latitud                     float64
# dtype: object

# %%
causalidad_accidentes_2017.shape
# Out:
# (10343, 23)

# %% [markdown]
# A continuación se seleccionan en cada uno de los 3 DataFrames las columnas de interés; en el caso de causalidad de accidentes se utilizan el número de expediente, el codigo del distrito, el nombre del distrito, el codigo del barrio, el nombre del barrio, el día de la semana, el año, el mes, el día, la hora, la causalidad y las dos coordenadas UTM.
# En segundo lugar se renombran los nombres de las columnas al castellano para luego poder juntar los 3 DataFrames.

# %%
columnas = [0,1,2,3,4,8,11,12,14,15,17,18,19]
causalidad_accidentes_2015 = causalidad_accidentes_2015.iloc[:,columnas]
causalidad_accidentes_2015.head()
# Out:
#   Número d expedient  Codi districte Nom districte  Codi barri  \
# 0        2015S005022              10    Sant Martí          64
# 1        2015S000390              10    Sant Martí          64
# 2        2015S001866              10    Sant Martí          64
# 3        2015S004932              10    Sant Martí          64
# 4        2015S007776              10    Sant Martí          64
#
#                     Nom barri Descripció dia setmana  NK Any  Mes de any  \
# 0  el Camp de l'Arpa del Clot                Dimarts    2015           6
# 1  el Camp de l'Arpa del Clot               Dissabte    2015           1
# 2  el Camp de l'Arpa del Clot               Dimecres    2015           3
# 3  el Camp de l'Arpa del Clot              Divendres    2015           6
# 4  el Camp de l'Arpa del Clot              Divendres    2015          10
#
#    Dia de mes  Hora de dia Descripció causa mediata Coordenada UTM (Y)  \
# 0          30            0   No hi ha causa mediata         4585292,35
# 1          17            0   No hi ha causa mediata         4585157,93
# 2          11            8   No hi ha causa mediata         4585458,06
# 3          26           14   No hi ha causa mediata         4584962,11
# 4          16           16   No hi ha causa mediata         4585010,37
#
#   Coordenada UTM (X)
# 0          431831,05
# 1          431472,27
# 2          431634,78
# 3          431474,34
# 4          431378,26

# %%
causalidad_accidentes_2015.rename(columns={"Número d expedient":'Num_expediente',"Codi districte":"Cod_distrito","Nom districte":"Nombre_distrito","Codi barri":"Cod_barrio","Nom barri":"Nombre_barrio","Descripció dia setmana":"Dia_semana","NK Any":"Anio","Mes de any":"Mes","Dia de mes":"Dia","Hora de dia":"Hora","Descripció causa mediata":"Causalidad","Coordenada UTM (Y)":"UTM_Y","Coordenada UTM (X)":"UTM_X"}, inplace=True)
causalidad_accidentes_2015.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Anio  Mes  Dia  Hora  \
# 0  el Camp de l'Arpa del Clot    Dimarts  2015    6   30     0
# 1  el Camp de l'Arpa del Clot   Dissabte  2015    1   17     0
# 2  el Camp de l'Arpa del Clot   Dimecres  2015    3   11     8
# 3  el Camp de l'Arpa del Clot  Divendres  2015    6   26    14
# 4  el Camp de l'Arpa del Clot  Divendres  2015   10   16    16
#
#                Causalidad       UTM_Y      UTM_X
# 0  No hi ha causa mediata  4585292,35  431831,05
# 1  No hi ha causa mediata  4585157,93  431472,27
# 2  No hi ha causa mediata  4585458,06  431634,78
# 3  No hi ha causa mediata  4584962,11  431474,34
# 4  No hi ha causa mediata  4585010,37  431378,26

# %%
causalidad_accidentes_2016 = causalidad_accidentes_2016.iloc[:,columnas]
causalidad_accidentes_2016.head()
# Out:
#   Número d'expedient  Codi districte        Nom districte  Codi barri  \
# 0    2016S004659                   5  Sarrià-Sant Gervasi          22
# 1    2016S008630                   5  Sarrià-Sant Gervasi          22
# 2    2016S009877                   5  Sarrià-Sant Gervasi          22
# 3    2016S002188                   5  Sarrià-Sant Gervasi          22
# 4    2016S004036                   5  Sarrià-Sant Gervasi          22
#
#                                Nom barri Descripció dia setmana  NK Any  \
# 0  Vallvidrera, el Tibidabo i les Planes               Dimecres    2016
# 1  Vallvidrera, el Tibidabo i les Planes                 Dijous    2016
# 2  Vallvidrera, el Tibidabo i les Planes               Dimecres    2016
# 3  Vallvidrera, el Tibidabo i les Planes               Dissabte    2016
# 4  Vallvidrera, el Tibidabo i les Planes                 Dijous    2016
#
#    Mes de any  Dia de mes  Hora de dia Descripció causa mediata  \
# 0           6          15           11   No hi ha causa mediata
# 1          11          10           19   No hi ha causa mediata
# 2          12          21           18   No hi ha causa mediata
# 3           3          19            7   No hi ha causa mediata
# 4           5          26            7   No hi ha causa mediata
#
#   Coordenada UTM (X) Coordenada UTM (Y)
# 0          423606,83         4586843,04
# 1          424249,09         4586527,04
# 2          424262,40         4586543,35
# 3          424412,65         4585743,93
# 4          424610,52         4585995,05

# %%
causalidad_accidentes_2016.rename(columns={"Número d'expedient":'Num_expediente',"Codi districte":"Cod_distrito","Nom districte":"Nombre_distrito","Codi barri":"Cod_barrio","Nom barri":"Nombre_barrio","Descripció dia setmana":"Dia_semana","NK Any":"Anio","Mes de any":"Mes","Dia de mes":"Dia","Hora de dia":"Hora","Descripció causa mediata":"Causalidad","Coordenada UTM (Y)":"UTM_Y","Coordenada UTM (X)":"UTM_X"}, inplace=True)
causalidad_accidentes_2016.head()
# Out:
#     Num_expediente  Cod_distrito      Nombre_distrito  Cod_barrio  \
# 0  2016S004659                 5  Sarrià-Sant Gervasi          22
# 1  2016S008630                 5  Sarrià-Sant Gervasi          22
# 2  2016S009877                 5  Sarrià-Sant Gervasi          22
# 3  2016S002188                 5  Sarrià-Sant Gervasi          22
# 4  2016S004036                 5  Sarrià-Sant Gervasi          22
#
#                            Nombre_barrio Dia_semana  Anio  Mes  Dia  Hora  \
# 0  Vallvidrera, el Tibidabo i les Planes   Dimecres  2016    6   15    11
# 1  Vallvidrera, el Tibidabo i les Planes     Dijous  2016   11   10    19
# 2  Vallvidrera, el Tibidabo i les Planes   Dimecres  2016   12   21    18
# 3  Vallvidrera, el Tibidabo i les Planes   Dissabte  2016    3   19     7
# 4  Vallvidrera, el Tibidabo i les Planes     Dijous  2016    5   26     7
#
#                Causalidad      UTM_X       UTM_Y
# 0  No hi ha causa mediata  423606,83  4586843,04
# 1  No hi ha causa mediata  424249,09  4586527,04
# 2  No hi ha causa mediata  424262,40  4586543,35
# 3  No hi ha causa mediata  424412,65  4585743,93
# 4  No hi ha causa mediata  424610,52  4585995,05

# %%
columnas = [0,1,2,3,4,9,12,13,15,16,18,19,20]
causalidad_accidentes_2017 = causalidad_accidentes_2017.iloc[:,columnas]
causalidad_accidentes_2017.head()
# Out:
#   Número_d'expedient  Codi_districte Nom_districte  Codi_barri  \
# 0    2017S009198                  10    Sant Martí          64
# 1    2017S008278                  10    Sant Martí          64
# 2    2017S008462                  10    Sant Martí          64
# 3    2017S001826                  10    Sant Martí          64
# 4    2017S009733                  10    Sant Martí          64
#
#                     Nom_barri Descripció_dia_setmana  NK Any  Mes_de_any  \
# 0  el Camp de l'Arpa del Clot                Dimarts    2017          11
# 1  el Camp de l'Arpa del Clot               Dissabte    2017          10
# 2  el Camp de l'Arpa del Clot               Dissabte    2017          10
# 3  el Camp de l'Arpa del Clot                Dilluns    2017           3
# 4  el Camp de l'Arpa del Clot                 Dijous    2017          11
#
#    Dia_de_mes  Hora_de_dia Descripció_causa_mediata Coordenada_UTM_(X)  \
# 0           7           14   No hi ha causa mediata          431940,75
# 1           7           12   No hi ha causa mediata          431576,37
# 2          14           13   No hi ha causa mediata          431384,99
# 3           6            4              Alcoholèmia          431703,06
# 4          23            8   No hi ha causa mediata          431877,03
#
#   Coordenada_UTM_(Y)
# 0         4585401,48
# 1         4585215,20
# 2         4584870,55
# 3         4584790,47
# 4         4584413,10

# %%
causalidad_accidentes_2017.rename(columns={"Número_d'expedient":'Num_expediente',"Codi_districte":"Cod_distrito","Nom_districte":"Nombre_distrito","Codi_barri":"Cod_barrio","Nom_barri":"Nombre_barrio","Descripció_dia_setmana":"Dia_semana","NK Any":"Anio","Mes_de_any":"Mes","Dia_de_mes":"Dia","Hora_de_dia":"Hora","Descripció_causa_mediata":"Causalidad","Coordenada_UTM_(Y)":"UTM_Y","Coordenada_UTM_(X)":"UTM_X"}, inplace=True)
causalidad_accidentes_2017.head()
# Out:
#     Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0  2017S009198                10      Sant Martí          64
# 1  2017S008278                10      Sant Martí          64
# 2  2017S008462                10      Sant Martí          64
# 3  2017S001826                10      Sant Martí          64
# 4  2017S009733                10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Anio  Mes  Dia  Hora  \
# 0  el Camp de l'Arpa del Clot    Dimarts  2017   11    7    14
# 1  el Camp de l'Arpa del Clot   Dissabte  2017   10    7    12
# 2  el Camp de l'Arpa del Clot   Dissabte  2017   10   14    13
# 3  el Camp de l'Arpa del Clot    Dilluns  2017    3    6     4
# 4  el Camp de l'Arpa del Clot     Dijous  2017   11   23     8
#
#                Causalidad      UTM_X       UTM_Y
# 0  No hi ha causa mediata  431940,75  4585401,48
# 1  No hi ha causa mediata  431576,37  4585215,20
# 2  No hi ha causa mediata  431384,99  4584870,55
# 3             Alcoholèmia  431703,06  4584790,47
# 4  No hi ha causa mediata  431877,03  4584413,10

# %% [markdown]
# Se juntan los 3 DataFrames en un unico DataFrame

# %%
causalidad_accidentes = causalidad_accidentes_2015.append(causalidad_accidentes_2016, ignore_index=True, verify_integrity=True, sort=False)
causalidad_accidentes = causalidad_accidentes.append(causalidad_accidentes_2017, ignore_index=True, verify_integrity=True, sort=False)
len(causalidad_accidentes) == len(causalidad_accidentes_2015) + len(causalidad_accidentes_2016) + len(causalidad_accidentes_2017)
# Out:
# True

# %%
causalidad_accidentes.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Anio  Mes  Dia  Hora  \
# 0  el Camp de l'Arpa del Clot    Dimarts  2015    6   30     0
# 1  el Camp de l'Arpa del Clot   Dissabte  2015    1   17     0
# 2  el Camp de l'Arpa del Clot   Dimecres  2015    3   11     8
# 3  el Camp de l'Arpa del Clot  Divendres  2015    6   26    14
# 4  el Camp de l'Arpa del Clot  Divendres  2015   10   16    16
#
#                Causalidad       UTM_Y      UTM_X
# 0  No hi ha causa mediata  4585292,35  431831,05
# 1  No hi ha causa mediata  4585157,93  431472,27
# 2  No hi ha causa mediata  4585458,06  431634,78
# 3  No hi ha causa mediata  4584962,11  431474,34
# 4  No hi ha causa mediata  4585010,37  431378,26

# %% [markdown]
# Se verifica que los números de expediente sean integros. Se observa que hay números que terminan con espacios blancos, entonces se quitan.

# %%
causalidad_accidentes['Num_expediente'].unique()
# Out:
# array(['2015S005022', '2015S000390', '2015S001866', ...,
#        '2017S009755    ', '2017S008017    ', '2017S009181    '],
#       dtype=object)

# %%
def elimina_espacios(fila):
    return (fila.Num_expediente).strip()

causalidad_accidentes['Num_expediente'] = causalidad_accidentes.apply(elimina_espacios, axis=1)
causalidad_accidentes['Num_expediente'].unique()
# Out:
# array(['2015S005022', '2015S000390', '2015S001866', ..., '2017S009755',
#        '2017S008017', '2017S009181'], dtype=object)

# %% [markdown]
# Se verifica que los datos del distrito (código y nombre) sean integros

# %%
filtra_distritos = causalidad_accidentes.iloc[:,1:3]
filtra_distritos = filtra_distritos.drop_duplicates()
filtra_distritos
# Out:
#       Cod_distrito      Nombre_distrito
# 0               10           Sant Martí
# 148              1         Ciutat Vella
# 222              2             Eixample
# 556              3       Sants-Montjuïc
# 734              4            Les Corts
# 818              5  Sarrià-Sant Gervasi
# 954              6               Gràcia
# 1024             7       Horta-Guinardó
# 1121             8           Nou Barris
# 1190             9          Sant Andreu
# 1263            -1           Desconegut

# %% [markdown]
# Se hace lo mismo por los barrios

# %%
filtra_barrios = causalidad_accidentes.iloc[:,3:5]
filtra_barrios = filtra_barrios.drop_duplicates()
filtra_barrios
# Out:
#        Cod_barrio                                 Nombre_barrio
# 0              64                    el Camp de l'Arpa del Clot
# 21             65                                       el Clot
# 35             72                      Sant Martí de Provençals
# 53             73                           la Verneda i la Pau
# 56             70                         el Besòs i el Maresme
# 63             71                       Provençals del Poblenou
# 86             68                                   el Poblenou
# 106            69  Diagonal Mar i el Front Marítim del Poblenou
# 110            66             el Parc i la Llacuna del Poblenou
# 131            67                 la Vila Olímpica del Poblenou
# 148             1                                      el Raval
# 168             2                                el Barri Gòtic
# 199             3                                la Barceloneta
# 208             4         Sant Pere, Santa Caterina i la Ribera
# 222            10                                   Sant Antoni
# 232             9                la Nova Esquerra de l'Eixample
# 295             8               l'Antiga Esquerra de l'Eixample
# 352             7                        la Dreta de l'Eixample
# 477             6                            la Sagrada Família
# 549             5                                 el Fort Pienc
# 556            11                                  el Poble Sec
# 613            12                    la Marina del Prat Vermell
# 657            13                             la Marina de Port
# 662            14                         la Font de la Guatlla
# 670            15                                   Hostafrancs
# 688            16                                    la Bordeta
# 693            17                                 Sants - Badal
# 709            18                                         Sants
# 734            19                                     les Corts
# 763            20                    la Maternitat i Sant Ramon
# ...           ...                                           ...
# 1036           40                                       Montbau
# 1041           36                          la Font d'en Fargues
# 1048           42                                      la Clota
# 1054           43                                         Horta
# 1076           34                                      Can Baró
# 1080           37                                     el Carmel
# 1092           33                              el Baix Guinardó
# 1099           35                                   el Guinardó
# 1121           54                                    Torre Baró
# 1128           49                                     Canyelles
# 1132           50                                  les Roquetes
# 1141           48                                  la Guineueta
# 1142           53                              la Trinitat Nova
# 1164           51                                        Verdun
# 1165           52                                la Prosperitat
# 1169           44                 Vilapicina i la Torre Llobeta
# 1175           45                                         Porta
# 1186           46                           el Turó de la Peira
# 1190           61                                    la Sagrera
# 1194           62                      el Congrés i els Indians
# 1198           63                                         Navas
# 1206           60                                   Sant Andreu
# 1236           57                             la Trinitat Vella
# 1241           58                                 Baró de Viver
# 1244           59                                 el Bon Pastor
# 1263           -1                                    Desconegut
# 2330           56                                      Vallbona
# 2396           47                                   Can Peguera
# 3632           55                              Ciutat Meridiana
# 20358          11                                  el Poble-sec
#
# [75 rows x 2 columns]

# %% [markdown]
# Se observa que el barrio de "el Poble Sec" aparece también con el nombre de "el Poble-sec", entonces se modifica

# %%
def modifica_barrio(a):
    barrio = a.Nombre_barrio
    if barrio == 'el Poble-sec':
        b = 'el Poble Sec'
    else:
        b = barrio
    return b
   
causalidad_accidentes['Nombre_barrio'] = causalidad_accidentes.apply(modifica_barrio, axis=1)  
filtra_barrios = causalidad_accidentes.iloc[:,3:5]
filtra_barrios = filtra_barrios.drop_duplicates()
filtra_barrios
# Out:
#       Cod_barrio                                 Nombre_barrio
# 0             64                    el Camp de l'Arpa del Clot
# 21            65                                       el Clot
# 35            72                      Sant Martí de Provençals
# 53            73                           la Verneda i la Pau
# 56            70                         el Besòs i el Maresme
# 63            71                       Provençals del Poblenou
# 86            68                                   el Poblenou
# 106           69  Diagonal Mar i el Front Marítim del Poblenou
# 110           66             el Parc i la Llacuna del Poblenou
# 131           67                 la Vila Olímpica del Poblenou
# 148            1                                      el Raval
# 168            2                                el Barri Gòtic
# 199            3                                la Barceloneta
# 208            4         Sant Pere, Santa Caterina i la Ribera
# 222           10                                   Sant Antoni
# 232            9                la Nova Esquerra de l'Eixample
# 295            8               l'Antiga Esquerra de l'Eixample
# 352            7                        la Dreta de l'Eixample
# 477            6                            la Sagrada Família
# 549            5                                 el Fort Pienc
# 556           11                                  el Poble Sec
# 613           12                    la Marina del Prat Vermell
# 657           13                             la Marina de Port
# 662           14                         la Font de la Guatlla
# 670           15                                   Hostafrancs
# 688           16                                    la Bordeta
# 693           17                                 Sants - Badal
# 709           18                                         Sants
# 734           19                                     les Corts
# 763           20                    la Maternitat i Sant Ramon
# ...          ...                                           ...
# 1035          41                              la Vall d'Hebron
# 1036          40                                       Montbau
# 1041          36                          la Font d'en Fargues
# 1048          42                                      la Clota
# 1054          43                                         Horta
# 1076          34                                      Can Baró
# 1080          37                                     el Carmel
# 1092          33                              el Baix Guinardó
# 1099          35                                   el Guinardó
# 1121          54                                    Torre Baró
# 1128          49                                     Canyelles
# 1132          50                                  les Roquetes
# 1141          48                                  la Guineueta
# 1142          53                              la Trinitat Nova
# 1164          51                                        Verdun
# 1165          52                                la Prosperitat
# 1169          44                 Vilapicina i la Torre Llobeta
# 1175          45                                         Porta
# 1186          46                           el Turó de la Peira
# 1190          61                                    la Sagrera
# 1194          62                      el Congrés i els Indians
# 1198          63                                         Navas
# 1206          60                                   Sant Andreu
# 1236          57                             la Trinitat Vella
# 1241          58                                 Baró de Viver
# 1244          59                                 el Bon Pastor
# 1263          -1                                    Desconegut
# 2330          56                                      Vallbona
# 2396          47                                   Can Peguera
# 3632          55                              Ciutat Meridiana
#
# [74 rows x 2 columns]

# %% [markdown]
# Buscando por internet, se puede verificar que efectivamente Barcelona tiene estos 10 distritos y 73 barrios (aquí 11 y 74 porque hay el valor "desconocido" en ambos casos). Entonces estos datos resultan ser integros.

# %% [markdown]
# Ahora se verifica que los datos de los días de la semana sean integros y se cambian los nombres al castellano

# %%
causalidad_accidentes.groupby('Dia_semana').count().iloc[:,1]
# Out:
# Dia_semana
# Dijous       5032
# Dilluns      4519
# Dimarts      4864
# Dimecres     4970
# Dissabte     3348
# Diumenge     2571
# Divendres    5216
# Name: Cod_distrito, dtype: int64

# %%
def modifica_dia_semana(a):
    dia = a.Dia_semana
    if dia == 'Dijous':
        b='jueves'
    elif dia == 'Dilluns':
        b='lunes'
    elif dia == 'Dimarts':
        b='martes'
    elif dia == 'Dimecres':
        b='miercoles'
    elif dia == 'Dissabte':
        b='sabado'
    elif dia == 'Diumenge':
        b='domingo'
    elif dia == 'Divendres':
        b='viernes'
    return b
   
causalidad_accidentes['Dia_semana'] = causalidad_accidentes.apply(modifica_dia_semana, axis=1)       
causalidad_accidentes.groupby('Dia_semana').count().iloc[:,1]
# Out:
# Dia_semana
# domingo      2571
# jueves       5032
# lunes        4519
# martes       4864
# miercoles    4970
# sabado       3348
# viernes      5216
# Name: Cod_distrito, dtype: int64

# %% [markdown]
# Se verifica que los datos de año, mes y día sean integros y se transforman estos 3 campos en un unico campo "fecha". Por eso, se tienen que transformar antes los 3 campos a string, luego juntarlos y en fin convertirlos en datetime.strptime

# %%
causalidad_accidentes['Anio'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
causalidad_accidentes['Mes'].unique()
# Out:
# array([ 6,  1,  3, 10,  7,  9,  4,  8,  5, 11,  2, 12])

# %%
causalidad_accidentes['Dia'].unique()
# Out:
# array([30, 17, 11, 26, 16,  2, 23, 19, 14,  1,  4, 24, 27,  7,  8, 12, 22,
#         3, 10, 25, 18, 29, 13,  9, 28, 21,  6,  5, 20, 15, 31])

# %%
causalidad_accidentes['Anio'] = causalidad_accidentes['Anio'].astype(str)
causalidad_accidentes['Mes'] = causalidad_accidentes['Mes'].astype(str)
causalidad_accidentes['Dia'] = causalidad_accidentes['Dia'].astype(str)

# %%
causalidad_accidentes.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Anio Mes Dia  Hora  \
# 0  el Camp de l'Arpa del Clot     martes  2015   6  30     0
# 1  el Camp de l'Arpa del Clot     sabado  2015   1  17     0
# 2  el Camp de l'Arpa del Clot  miercoles  2015   3  11     8
# 3  el Camp de l'Arpa del Clot    viernes  2015   6  26    14
# 4  el Camp de l'Arpa del Clot    viernes  2015  10  16    16
#
#                Causalidad       UTM_Y      UTM_X
# 0  No hi ha causa mediata  4585292,35  431831,05
# 1  No hi ha causa mediata  4585157,93  431472,27
# 2  No hi ha causa mediata  4585458,06  431634,78
# 3  No hi ha causa mediata  4584962,11  431474,34
# 4  No hi ha causa mediata  4585010,37  431378,26

# %%
causalidad_accidentes['Fecha'] = causalidad_accidentes.Dia + '/' + causalidad_accidentes.Mes + '/' + causalidad_accidentes.Anio
causalidad_accidentes.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Anio Mes Dia  Hora  \
# 0  el Camp de l'Arpa del Clot     martes  2015   6  30     0
# 1  el Camp de l'Arpa del Clot     sabado  2015   1  17     0
# 2  el Camp de l'Arpa del Clot  miercoles  2015   3  11     8
# 3  el Camp de l'Arpa del Clot    viernes  2015   6  26    14
# 4  el Camp de l'Arpa del Clot    viernes  2015  10  16    16
#
#                Causalidad       UTM_Y      UTM_X       Fecha
# 0  No hi ha causa mediata  4585292,35  431831,05   30/6/2015
# 1  No hi ha causa mediata  4585157,93  431472,27   17/1/2015
# 2  No hi ha causa mediata  4585458,06  431634,78   11/3/2015
# 3  No hi ha causa mediata  4584962,11  431474,34   26/6/2015
# 4  No hi ha causa mediata  4585010,37  431378,26  16/10/2015

# %%
def formato_fecha(fila):
    a = datetime.strptime(fila.Fecha,'%d/%m/%Y')
    return a
    
causalidad_accidentes['Fecha'] = causalidad_accidentes.apply(formato_fecha, axis=1)
causalidad_accidentes.dtypes
# Out:
# Num_expediente             object
# Cod_distrito                int64
# Nombre_distrito            object
# Cod_barrio                  int64
# Nombre_barrio              object
# Dia_semana                 object
# Anio                       object
# Mes                        object
# Dia                        object
# Hora                        int64
# Causalidad                 object
# UTM_Y                      object
# UTM_X                      object
# Fecha              datetime64[ns]
# dtype: object

# %%
causalidad_accidentes.drop(["Anio", "Mes", "Dia"], axis = 1, inplace = True)
causalidad_accidentes.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Hora              Causalidad  \
# 0  el Camp de l'Arpa del Clot     martes     0  No hi ha causa mediata
# 1  el Camp de l'Arpa del Clot     sabado     0  No hi ha causa mediata
# 2  el Camp de l'Arpa del Clot  miercoles     8  No hi ha causa mediata
# 3  el Camp de l'Arpa del Clot    viernes    14  No hi ha causa mediata
# 4  el Camp de l'Arpa del Clot    viernes    16  No hi ha causa mediata
#
#         UTM_Y      UTM_X      Fecha
# 0  4585292,35  431831,05 2015-06-30
# 1  4585157,93  431472,27 2015-01-17
# 2  4585458,06  431634,78 2015-03-11
# 3  4584962,11  431474,34 2015-06-26
# 4  4585010,37  431378,26 2015-10-16

# %% [markdown]
# Se tiene que verificar que todas las horas almacenadas sean >= 0 y < 24

# %%
causalidad_accidentes['Hora'].unique()
# Out:
# array([ 0,  8, 14, 16, 22, 10, 11,  7, 15, 17, 20, 12, 13, 21, 23, 18,  9,
#        19,  3,  1,  5,  4,  6,  2])

# %% [markdown]
# Ahora se verifica que los datos de causalidad sean integros y se cambian los nombres al castellano

# %%
causalidad_accidentes['Causalidad'].unique()
# Out:
# array(['No hi ha causa mediata', 'Excés de velocitat o inadequada',
#        'Alcoholèmia', 'Calçada en mal estat', 'Drogues o medicaments',
#        'Estat de la senyalització', 'Factors meteorològics',
#        'Objectes o animals a la calçada'], dtype=object)

# %%
def modifica_causalidad(a):
    causalidad = a.Causalidad
    if causalidad == 'No hi ha causa mediata':
        b='No hay causa mediata'
    elif causalidad == 'Excés de velocitat o inadequada':
        b='Exceso de velocidad o inadecuada'
    elif causalidad == 'Alcoholèmia':
        b='Alcoholemia'
    elif causalidad == 'Calçada en mal estat':
        b='Calzada en mal estado'
    elif causalidad == 'Drogues o medicaments':
        b='Drogas o medicamentos'
    elif causalidad == 'Estat de la senyalització':
        b='Estado de la señalización'
    elif causalidad == 'Factors meteorològics':
        b='Factores meteorológicos'
    elif causalidad == 'Objectes o animals a la calçada':
        b='Objetos o animales en la calzada'
    else:
        b = causalidad
    return b
   
causalidad_accidentes['Causalidad'] = causalidad_accidentes.apply(modifica_causalidad, axis=1)       
causalidad_accidentes['Causalidad'].unique()
# Out:
# array(['No hay causa mediata', 'Exceso de velocidad o inadecuada',
#        'Alcoholemia', 'Calzada en mal estado', 'Drogas o medicamentos',
#        'Estado de la señalización', 'Factores meteorológicos',
#        'Objetos o animales en la calzada'], dtype=object)

# %% [markdown]
# Ahora se quieren cambiar las coordenadas UTM a latitud y longitud, que se necesitan para diseñar los puntos en los mapas

# %%
def UTM(utm):
    if type(utm) is str:
        b = float(utm.replace(',' ,'.'))
    else:
        b = utm
    return b

causalidad_accidentes['UTM_Y'] = causalidad_accidentes['UTM_Y'].apply(UTM)
causalidad_accidentes['UTM_X'] = causalidad_accidentes['UTM_X'].apply(UTM)
causalidad_accidentes.dtypes
# Out:
# Num_expediente             object
# Cod_distrito                int64
# Nombre_distrito            object
# Cod_barrio                  int64
# Nombre_barrio              object
# Dia_semana                 object
# Hora                        int64
# Causalidad                 object
# UTM_Y                     float64
# UTM_X                     float64
# Fecha              datetime64[ns]
# dtype: object

# %% [markdown]
# Se observa que hay una pareja de coordenadas negativas, que se asume sean desconocidas. En la conversión de UTM a latitud y longitud se ignora esta pareja y durante el estudio se asume desconocida

# %%
causalidad_accidentes[causalidad_accidentes.index == 404]
# Out:
#     Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 404    2015S008826             2        Eixample           7
#
#               Nombre_barrio Dia_semana  Hora            Causalidad  UTM_Y  \
# 404  la Dreta de l'Eixample    domingo    21  No hay causa mediata   -1.0
#
#      UTM_X      Fecha
# 404   -1.0 2015-11-22

# %%
import utm

def ignora_negativos (fila):
    if fila.UTM_X > 0.0 and fila.UTM_Y > 0.0:
        return utm.to_latlon(fila.UTM_X, fila.UTM_Y, 31 ,'T')
    else:
        return (-1.0, -1.0)
        
causalidad_accidentes['latlon'] = causalidad_accidentes.apply(ignora_negativos, axis=1)
causalidad_accidentes.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Hora            Causalidad  \
# 0  el Camp de l'Arpa del Clot     martes     0  No hay causa mediata
# 1  el Camp de l'Arpa del Clot     sabado     0  No hay causa mediata
# 2  el Camp de l'Arpa del Clot  miercoles     8  No hay causa mediata
# 3  el Camp de l'Arpa del Clot    viernes    14  No hay causa mediata
# 4  el Camp de l'Arpa del Clot    viernes    16  No hay causa mediata
#
#         UTM_Y      UTM_X      Fecha                                    latlon
# 0  4585292.35  431831.05 2015-06-30    (41.41629410168425, 2.184294161883998)
# 1  4585157.93  431472.27 2015-01-17   (41.41505291062014, 2.1800166681639714)
# 2  4585458.06  431634.78 2015-03-11    (41.41776992245236, 2.181927106661357)
# 3  4584962.11  431474.34 2015-06-26    (41.41328940203058, 2.180063615116817)
# 4  4585010.37  431378.26 2015-10-16  (41.413715865571994, 2.1789086195051635)

# %%
causalidad_accidentes['Latitud'] = causalidad_accidentes.apply(lambda f: f.latlon[0], axis=1)
causalidad_accidentes['Longitud'] = causalidad_accidentes.apply(lambda f: f.latlon[1], axis=1)
causalidad_accidentes.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Hora            Causalidad  \
# 0  el Camp de l'Arpa del Clot     martes     0  No hay causa mediata
# 1  el Camp de l'Arpa del Clot     sabado     0  No hay causa mediata
# 2  el Camp de l'Arpa del Clot  miercoles     8  No hay causa mediata
# 3  el Camp de l'Arpa del Clot    viernes    14  No hay causa mediata
# 4  el Camp de l'Arpa del Clot    viernes    16  No hay causa mediata
#
#         UTM_Y      UTM_X      Fecha                                    latlon  \
# 0  4585292.35  431831.05 2015-06-30    (41.41629410168425, 2.184294161883998)
# 1  4585157.93  431472.27 2015-01-17   (41.41505291062014, 2.1800166681639714)
# 2  4585458.06  431634.78 2015-03-11    (41.41776992245236, 2.181927106661357)
# 3  4584962.11  431474.34 2015-06-26    (41.41328940203058, 2.180063615116817)
# 4  4585010.37  431378.26 2015-10-16  (41.413715865571994, 2.1789086195051635)
#
#      Latitud  Longitud
# 0  41.416294  2.184294
# 1  41.415053  2.180017
# 2  41.417770  2.181927
# 3  41.413289  2.180064
# 4  41.413716  2.178909

# %%
causalidad_accidentes.drop(["UTM_Y", "UTM_X", "latlon"], axis = 1, inplace = True)
causalidad_accidentes.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Hora            Causalidad  \
# 0  el Camp de l'Arpa del Clot     martes     0  No hay causa mediata
# 1  el Camp de l'Arpa del Clot     sabado     0  No hay causa mediata
# 2  el Camp de l'Arpa del Clot  miercoles     8  No hay causa mediata
# 3  el Camp de l'Arpa del Clot    viernes    14  No hay causa mediata
# 4  el Camp de l'Arpa del Clot    viernes    16  No hay causa mediata
#
#        Fecha    Latitud  Longitud
# 0 2015-06-30  41.416294  2.184294
# 1 2015-01-17  41.415053  2.180017
# 2 2015-03-11  41.417770  2.181927
# 3 2015-06-26  41.413289  2.180064
# 4 2015-10-16  41.413716  2.178909

# %% [markdown]
# Se intenta diseñar los puntos en el mapa y se observa que hay un gran número de accidentes en los parques. Esto parece raro, entonces se busca si hay un error de deslizamiento comparando las latitud y longitud obtenidas con los csv originales que tienen los datos de latitud y longitud. Se encuentra que hay un deslizamiento de 0.00185 en la latitud y 0.00111 en la longitud, entonces se arregla.

# %%
import geopandas as gpd
import folium

m = folium.Map(location=[41.4075163,2.1491085], zoom_start=20)
causalidad_accidentes.apply(lambda f: folium.Marker([f.Latitud, f.Longitud]).add_to(m), axis=1)
m

# %%
def arregla_latlon (fila):
    if fila.Latitud > 0.0 and fila.Longitud > 0.0:
        return (fila.Latitud - 0.00185, fila.Longitud - 0.001111)
    else:
        return (-1.0, -1.0)
        
causalidad_accidentes['Latitud','Longitud'] = causalidad_accidentes.apply(arregla_latlon, axis=1)

m = folium.Map(location=[41.4075163,2.1491085], zoom_start=20)
causalidad_accidentes.apply(lambda f: folium.Marker([f.Latitud, f.Longitud]).add_to(m), axis=1)
m

# %% [markdown]
# A continuación se exporta a un .csv

# %%
causalidad_accidentes.to_csv("Causalidad_Accidentes.csv",index=0, encoding="utf-8")

# %% [markdown]
# Se repite el proceso de importación pero esta vez con el nuevo csv para comprobar que se transformó correctamente

# %%
prueba=pd.read_csv('Causalidad_Accidentes.csv', index_col=False)

# %%
prueba.head()
# Out:
#   Num_expediente  Cod_distrito Nombre_distrito  Cod_barrio  \
# 0    2015S005022            10      Sant Martí          64
# 1    2015S000390            10      Sant Martí          64
# 2    2015S001866            10      Sant Martí          64
# 3    2015S004932            10      Sant Martí          64
# 4    2015S007776            10      Sant Martí          64
#
#                 Nombre_barrio Dia_semana  Hora            Causalidad  \
# 0  el Camp de l'Arpa del Clot     martes     0  No hay causa mediata
# 1  el Camp de l'Arpa del Clot     sabado     0  No hay causa mediata
# 2  el Camp de l'Arpa del Clot  miercoles     8  No hay causa mediata
# 3  el Camp de l'Arpa del Clot    viernes    14  No hay causa mediata
# 4  el Camp de l'Arpa del Clot    viernes    16  No hay causa mediata
#
#         Fecha    Latitud  Longitud
# 0  2015-06-30  41.416294  2.184294
# 1  2015-01-17  41.415053  2.180017
# 2  2015-03-11  41.417770  2.181927
# 3  2015-06-26  41.413289  2.180064
# 4  2015-10-16  41.413716  2.178909

# %%
prueba.tail()
# Out:
#       Num_expediente  Cod_distrito      Nombre_distrito  Cod_barrio  \
# 30515    2017S004066             3       Sants-Montjuïc          12
# 30516    2017S009306             7       Horta-Guinardó          33
# 30517    2017S009755            10           Sant Martí          71
# 30518    2017S008017             5  Sarrià-Sant Gervasi          26
# 30519    2017S009181             6               Gràcia          32
#
#                             Nombre_barrio Dia_semana  Hora  \
# 30515          la Marina del Prat Vermell      lunes    13
# 30516                    el Baix Guinardó    viernes    11
# 30517             Provençals del Poblenou     jueves    19
# 30518              Sant Gervasi - Galvany     jueves    20
# 30519  el Camp d'en Grassot i Gràcia Nova     martes     9
#
#                  Causalidad       Fecha    Latitud  Longitud
# 30515  No hay causa mediata  2017-05-08  41.372110  2.175281
# 30516  No hay causa mediata  2017-11-10  41.415769  2.168453
# 30517  No hay causa mediata  2017-11-23  41.410320  2.195000
# 30518  No hay causa mediata  2017-09-28  41.395153  2.146905
# 30519  No hay causa mediata  2017-11-07  41.406651  2.166765
