# %% [markdown]
# ## ACCIDENTES DE TRÁFICO EN BARCELONA##

# %% [markdown]
# El objetivo de este trabajo es analizar a través de tablas y gráficos los perfiles (edad y sexo) de las personas que más están involucradas en accidentes de tráfico y visualizar a través de un mapa la localización de los accidentes que han causado la muerte de las víctimas. Los datos los descargamos de la págína del ayuntamiento de Barcelona de los años 2016 y 2017 e involucra un archivo CSV: Personas involucradas.

# %% [markdown]
# ## Limpieza de datos##

# %% [markdown]
# Importación librerías para poder trabajar las bases

# %%
import pandas as pd
import re
from datetime import date, datetime

# %% [markdown]
# Exportación de la base personas involucradas en accidentes 2017

# %%
vict1_17 = pd.read_csv('2017_accidents_persones_gu_bcn_.csv', index_col=False)
# vict1_17.head()
vict1_17.loc[258]
# Out:
# Número_d'expedient                       2017S000210
# Codi_districte                                         2
# Nom districte                                   Eixample
# Codi_barri                                             6
# Nom_barri                             la Sagrada Família
# Codi_carrer                                        18505
# Nom carrer                                         Aragó
# Num_postal                                     0429 0429
# Descripció_dia_setmana                           Dimarts
# Dia setmana                                           Dm
# Descripció tipus dia                             Laboral
# NK Any                                              2017
# Mes de any                                             1
# Nom mes                                            Gener
# Dia de mes                                            10
# Descripció torn                                     Matí
# Hora de dia                                            8
# Descripció causa vianant        No és causa del  vianant
# Desc._Tipus_vehicle_implicat                 Motocicleta
# Descripció_sexe                                     Dona
# Edat                                                  27
# Descripció_tipus_persona                       Conductor
# Descripció_situació                           Presentado
# Descripció_victimització                      Ferit lleu
# Coordenada_UTM_(X)                             431320,08
# Coordenada_UTM_(Y)                            4583870,96
# Long                                            2.177239
# Lat                                            41.401594
# Name: 258, dtype: object

# %% [markdown]
# Inspección de los tipos de datos

# %%
vict1_17.dtypes
# Out:
# Número_d'expedient              object
# Codi_districte                   int64
# Nom districte                   object
# Codi_barri                       int64
# Nom_barri                       object
# Codi_carrer                      int64
# Nom carrer                      object
# Num_postal                      object
# Descripció_dia_setmana          object
# Dia setmana                     object
# Descripció tipus dia            object
# NK Any                           int64
# Mes de any                       int64
# Nom mes                         object
# Dia de mes                       int64
# Descripció torn                 object
# Hora de dia                      int64
# Descripció causa vianant        object
# Desc._Tipus_vehicle_implicat    object
# Descripció_sexe                 object
# Edat                            object
# Descripció_tipus_persona        object
# Descripció_situació             object
# Descripció_victimització        object
# Coordenada_UTM_(X)              object
# Coordenada_UTM_(Y)              object
# Long                            object
# Lat                             object
# dtype: object

# %% [markdown]
# Inspeccionar la cantidad de filas y columnas (12148 filas y 28 columnas)

# %%
vict1_17.shape
# Out:
# (12148, 28)

# %% [markdown]
# Exportamos la base de las personas involucradas en accidentes 2016

# %%
vict1_16 = pd.read_csv('2016_accidents_persones_gu_bcn.csv', index_col=False)
vict1_16.head(3)
# Out:
#   Número_d'expedient  Codi_districte Nom districte  Codi_barri  \
# 0    2016S000001                   2      Eixample           7
# 1    2016S000002                   1  Ciutat Vella           3
# 2    2016S000003                   8    Nou Barris          53
#
#                 Nom_barri  Codi_carrer Nom carrer Num_postal   \
# 0  la Dreta de l'Eixample       144601   Diagonal  0361B0361B
# 1          la Barceloneta       194202        Mar   0022 0022
# 2        la Trinitat Nova       209900  Meridiana  0595X0595X
#
#   Descripció_dia_setmana Dia setmana    ...     Desc._Tipus_vehicle_implicat  \
# 0              Divendres          Dv    ...                             Taxi
# 1              Divendres          Dv    ...                      Motocicleta
# 2              Divendres          Dv    ...                      Motocicleta
#
#    Descripció_sexe  Edat Descripció_tipus_persona  Descripció_situació  \
# 0             Home    41                Conductor           Presentado
# 1             Home    19                Passatger           Desconegut
# 2             Home    24                Conductor           Presentado
#
#   Descripció_victimització  Coordenada_UTM_(X) Coordenada_UTM_(Y)      Long  \
# 0               Ferit lleu           430142,09         4583396,02  2,163202
# 1               Ferit lleu           432161,38         4581525,86  2,187562
# 2               Ferit lleu           432262,30         4589063,89  2,187925
#
#          Lat
# 0  41,397223
# 1  41,380545
# 2  41,448446
#
# [3 rows x 28 columns]

# %% [markdown]
# Inspeccionar los tipos de datos

# %%
vict1_16.dtypes
# Out:
# Número_d'expedient              object
# Codi_districte                   int64
# Nom districte                   object
# Codi_barri                       int64
# Nom_barri                       object
# Codi_carrer                      int64
# Nom carrer                      object
# Num_postal                      object
# Descripció_dia_setmana          object
# Dia setmana                     object
# Descripció tipus dia            object
# NK Any                           int64
# Mes de any                       int64
# Nom mes                         object
# Dia de mes                       int64
# Descripció torn                 object
# Hora de dia                      int64
# Descripció causa vianant        object
# Desc._Tipus_vehicle_implicat    object
# Descripció_sexe                 object
# Edat                            object
# Descripció_tipus_persona        object
# Descripció_situació             object
# Descripció_victimització        object
# Coordenada_UTM_(X)              object
# Coordenada_UTM_(Y)              object
# Long                            object
# Lat                             object
# dtype: object

# %% [markdown]
# Inspeccionar la cantidad de filas y columnas (12072 filas y 28 columnas)

# %%
vict1_16.shape
# Out:
# (12072, 28)

# %% [markdown]
# Juntar las bases 2017 y 2016 de las personas involucradas y seleccionar/renombrar las columnas que nos interesa

# %%
# Juntar base 2017 y 2016 de personas involucradas 
victi = vict1_17.append(vict1_16, ignore_index=False, verify_integrity=False, sort=None)

# Seleccionar las columnas que nos interesan
vict_red = victi.iloc[:,[0,2,8,10,11,12,14,15,19,20,21,23,24,25]]

# Renombrar la columnas
vict_red.rename(columns={"Número_d'expedient":'NumExpediente','Nom districte': 'Distrito',
                               'Descripció_dia_setmana': 'DiaSemana','Descripció tipus dia':'TipoDia','NK Any':'Ano',
                               'Mes de any':'Mes','Dia de mes':'Dia','Descripció_sexe':'Sexo','Edat':'Edad',
                               'Descripció_tipus_persona':'TipoPersona','Descripció_victimització':'TriajeVictima',
                               'Coordenada_UTM_(X)':'C_UTM_X','Coordenada_UTM_(Y)':'C_UTM_Y','Descripció torn':'Horario'},
                      inplace=True)
vict_red.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      NumExpediente             Distrito DiaSemana  TipoDia   Ano  Mes  Dia  \
# 0  2017S000001      Sarrià-Sant Gervasi  Diumenge  Laboral  2017    1    1
# 1  2017S000002                 Eixample  Diumenge  Laboral  2017    1    1
# 2  2017S000004                 Eixample  Diumenge  Laboral  2017    1    1
# 3  2017S000005               Sant Martí  Diumenge  Laboral  2017    1    1
# 4  2017S000005               Sant Martí  Diumenge  Laboral  2017    1    1
#
#   Horario  Sexo Edad TipoPersona TriajeVictima    C_UTM_X     C_UTM_Y
# 0     Nit  Home   50   Conductor    Ferit lleu  428887,27  4583659,10
# 1     Nit  Home   47   Conductor    Ferit lleu  431987,02  4583282,61
# 2    Matí  Dona   27   Conductor    Ferit lleu  431615,63  4583971,63
# 3    Matí  Dona   40   Passatger    Ferit lleu  432466,78  4583327,27
# 4    Matí  Home   37   Conductor    Ferit lleu  432466,78  4583327,27

# %% [markdown]
# Inspeccionar filas y columnas (24220 filas y 14 columnas)

# %%
vict_red.shape
# Out:
# (24220, 14)

# %% [markdown]
# Ordenar tabla por nombre de distritos

# %%
vict_red.sort_values('Distrito', ascending=True).head(4)
# Out:
#          NumExpediente      Distrito DiaSemana  TipoDia   Ano  Mes  Dia  \
# 10654  2017S009535      Ciutat Vella    Dijous  Laboral  2017   11   16
# 3806   2017S003719      Ciutat Vella  Dimecres  Laboral  2017    4   26
# 8859   2017S008007      Ciutat Vella    Dijous  Laboral  2017    9   28
# 8860   2017S008007      Ciutat Vella    Dijous  Laboral  2017    9   28
#
#       Horario  Sexo Edad TipoPersona  \
# 10654   Tarda  Dona   53   Passatger
# 3806    Tarda  Home   62   Conductor
# 8859    Tarda  Dona   16   Passatger
# 8860    Tarda  Dona   76     Vianant
#
#                                    TriajeVictima    C_UTM_X     C_UTM_Y
# 10654     Ferit lleu: Hospitalització fins a 24h  431889,67  4581811,60
# 3806      Ferit lleu: Hospitalització fins a 24h  432525,41  4582138,01
# 8859      Ferit lleu: Hospitalització fins a 24h  432686,05  4581685,09
# 8860   Ferit lleu: Rebutja assistència sanitària  432686,05  4581685,09

# %% [markdown]
# Identificar el día con más accidentes

# %%
vict_red.groupby('DiaSemana', axis=0).count().iloc[:,1].sort_values(ascending=False)
# Out:
# DiaSemana
# Divendres    4086
# Dijous       4002
# Dimecres     3859
# Dimarts      3808
# Dilluns      3547
# Dissabte     2842
# Diumenge     2076
# Name: Distrito, dtype: int64

# %% [markdown]
# Tipo de personas involucradas en más accidentes en los años 2016 y 2017

# %%
vict_red.groupby(['TipoPersona','Ano'], axis=0).count().iloc[:,1]
# Out:
# TipoPersona  Ano
# Conductor    2016    8432
#              2017    8512
# Passatger    2016    2373
#              2017    2398
# Vianant      2016    1267
#              2017    1238
# Name: Distrito, dtype: int64

# %% [markdown]
# Convertir Edad en int, cambiando todo los Desconegut ('Desconocidos') a 666 para que todas la columna pueda ser considerada int

# %%
def cambiar(a):
    if a == 'Desconegut':
        a=666
    return int(a)

vict_red.Edad = vict_red.Edad.apply(cambiar)
vict_red.dtypes
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# NumExpediente    object
# Distrito         object
# DiaSemana        object
# TipoDia          object
# Ano               int64
# Mes               int64
# Dia               int64
# Horario          object
# Sexo             object
# Edad              int64
# TipoPersona      object
# TriajeVictima    object
# C_UTM_X          object
# C_UTM_Y          object
# dtype: object

# %% [markdown]
# Crear una función para dividir las edades por rangos y aplicarla sobre una nueva columna llamada RangoEdad (sabemos que esta operación implica un gasto de memoria y nunca se aplicaría en un caso real, pero en este caso lo hacemos como ejercicio adicional)

# %%
vict_red2 = vict_red.copy()

def rango_edad (fila) :
    valor=''
    if (fila.Edad) == 666 : 
        valor='Desconocido'
    elif 0<=(fila.Edad)<=20: 
        valor='Entre 0 y 20'
    elif 20<(fila.Edad)<=40: 
        valor='Entre 21 y 40'
    elif 40<(fila.Edad)<=60:
        valor='Entre 41 y 60'
    elif 60<(fila.Edad)<=80:
        valor='Entre 61 y 80'
    elif 80<(fila.Edad)<125:
        valor='Entre 81 a más'
    return valor

vict_red2['RangoEdad'] = vict_red2.apply(rango_edad, axis=1) 
vict_red2.groupby('RangoEdad').count().iloc[:,1]
# Out:
# RangoEdad
# Desconocido         172
# Entre 0 y 20       2235
# Entre 21 y 40     12359
# Entre 41 y 60      7146
# Entre 61 y 80      1817
# Entre 81 a más      491
# Name: Distrito, dtype: int64

# %% [markdown]
# Crear una función para cambiar todas las comas a puntos de la columna de C_UTM_X y castearlo a float

# %%
tmp1=vict_red2.copy()

def repcoor(fila):
    b=fila.C_UTM_X 
    if type(fila['C_UTM_X']) is str:
        b = float(fila['C_UTM_X'].replace(',' ,'.'))
    return b 

tmp1['C_UTM_X'] = tmp1.apply(repcoor,axis=1)
tmp1.head()
# Out:
#      NumExpediente             Distrito DiaSemana  TipoDia   Ano  Mes  Dia  \
# 0  2017S000001      Sarrià-Sant Gervasi  Diumenge  Laboral  2017    1    1
# 1  2017S000002                 Eixample  Diumenge  Laboral  2017    1    1
# 2  2017S000004                 Eixample  Diumenge  Laboral  2017    1    1
# 3  2017S000005               Sant Martí  Diumenge  Laboral  2017    1    1
# 4  2017S000005               Sant Martí  Diumenge  Laboral  2017    1    1
#
#   Horario  Sexo  Edad TipoPersona TriajeVictima    C_UTM_X     C_UTM_Y  \
# 0     Nit  Home    50   Conductor    Ferit lleu  428887.27  4583659,10
# 1     Nit  Home    47   Conductor    Ferit lleu  431987.02  4583282,61
# 2    Matí  Dona    27   Conductor    Ferit lleu  431615.63  4583971,63
# 3    Matí  Dona    40   Passatger    Ferit lleu  432466.78  4583327,27
# 4    Matí  Home    37   Conductor    Ferit lleu  432466.78  4583327,27
#
#        RangoEdad
# 0  Entre 41 y 60
# 1  Entre 41 y 60
# 2  Entre 21 y 40
# 3  Entre 21 y 40
# 4  Entre 21 y 40

# %% [markdown]
# Crear una función para cambiar todas las comas a puntos de la columna de C_UTM_X y castearlo a float

# %%
tmp2=tmp1.copy()

def repcoor(fila):
    b=fila.C_UTM_Y 
    if type(fila['C_UTM_Y']) is str:
        b = float(fila['C_UTM_Y'].replace(',' ,'.'))
    return b

tmp2['C_UTM_Y'] = tmp2.apply(repcoor,axis=1)
tmp2
# Out:
#          NumExpediente             Distrito  DiaSemana  TipoDia   Ano  Mes  \
# 0      2017S000001      Sarrià-Sant Gervasi   Diumenge  Laboral  2017    1
# 1      2017S000002                 Eixample   Diumenge  Laboral  2017    1
# 2      2017S000004                 Eixample   Diumenge  Laboral  2017    1
# 3      2017S000005               Sant Martí   Diumenge  Laboral  2017    1
# 4      2017S000005               Sant Martí   Diumenge  Laboral  2017    1
# 5      2017S000006             Ciutat Vella   Diumenge  Laboral  2017    1
# 6      2017S000008                 Eixample   Diumenge  Laboral  2017    1
# 7      2017S000008                 Eixample   Diumenge  Laboral  2017    1
# 8      2017S000009           Sants-Montjuïc   Diumenge  Laboral  2017    1
# 9      2017S000010              Sant Andreu   Diumenge  Laboral  2017    1
# 10     2017S000011               Sant Martí   Diumenge  Laboral  2017    1
# 11     2017S000012                 Eixample   Diumenge  Laboral  2017    1
# 12     2017S000012                 Eixample   Diumenge  Laboral  2017    1
# 13     2017S000013                 Eixample   Diumenge  Laboral  2017    1
# 14     2017S000014           Sants-Montjuïc   Diumenge  Laboral  2017    1
# 15     2017S000015               Sant Martí   Diumenge  Laboral  2017    1
# 16     2017S000015               Sant Martí   Diumenge  Laboral  2017    1
# 17     2017S000016                 Eixample   Diumenge  Laboral  2017    1
# 18     2017S000017               Sant Martí   Diumenge  Laboral  2017    1
# 19     2017S000017               Sant Martí   Diumenge  Laboral  2017    1
# 20     2017S000018                 Eixample   Diumenge  Laboral  2017    1
# 21     2017S000019               Sant Martí   Diumenge  Laboral  2017    1
# 22     2017S000022      Sarrià-Sant Gervasi   Diumenge  Laboral  2017    1
# 23     2017S000023           Sants-Montjuïc    Dimarts  Laboral  2017    1
# 24     2017S000023           Sants-Montjuïc    Dimarts  Laboral  2017    1
# 25     2017S000023           Sants-Montjuïc    Dimarts  Laboral  2017    1
# 26     2017S000024           Sants-Montjuïc    Dilluns  Laboral  2017    1
# 27     2017S000025                Les Corts    Dilluns  Laboral  2017    1
# 28     2017S000026           Sants-Montjuïc    Dilluns  Laboral  2017    1
# 29     2017S000027                   Gràcia    Dilluns  Laboral  2017    1
# ...                ...                  ...        ...      ...   ...  ...
# 12042  2016S010120      Sarrià-Sant Gervasi  Divendres  Laboral  2016   12
# 12043  2016S010122                 Eixample  Divendres  Laboral  2016   12
# 12044  2016S010122                 Eixample  Divendres  Laboral  2016   12
# 12045  2016S010122                 Eixample  Divendres  Laboral  2016   12
# 12046  2016S010123               Sant Martí  Divendres  Laboral  2016   12
# 12047  2016S010124             Ciutat Vella  Divendres  Laboral  2016   12
# 12048  2016S010126           Horta-Guinardó   Dissabte  Laboral  2016   12
# 12049  2016S010127                Les Corts  Divendres  Laboral  2016   12
# 12050  2016S010128           Horta-Guinardó   Dissabte  Laboral  2016   12
# 12051  2016S010128           Horta-Guinardó   Dissabte  Laboral  2016   12
# 12052  2016S010129               Nou Barris  Divendres  Laboral  2016   12
# 12053  2016S010130                 Eixample   Dissabte  Laboral  2016   12
# 12054  2016S010132                 Eixample   Dissabte  Laboral  2016   12
# 12055  2016S010133                Les Corts   Dissabte  Laboral  2016   12
# 12056  2016S010134           Horta-Guinardó   Dissabte  Laboral  2016   12
# 12057  2016S010135      Sarrià-Sant Gervasi   Dissabte  Laboral  2016   12
# 12058  2016S010136                 Eixample   Dissabte  Laboral  2016   12
# 12059  2016S010137               Nou Barris   Dissabte  Laboral  2016   12
# 12060  2016S010138               Nou Barris  Divendres  Laboral  2016   12
# 12061  2016S010139               Sant Martí   Dissabte  Laboral  2016   12
# 12062  2016S010139               Sant Martí   Dissabte  Laboral  2016   12
# 12063  2016S010140           Horta-Guinardó   Dissabte  Laboral  2016   12
# 12064  2016S010141              Sant Andreu   Dissabte  Laboral  2016   12
# 12065  2016S010142                   Gràcia   Dissabte  Laboral  2016   12
# 12066  2016S010143                   Gràcia   Dissabte  Laboral  2016   12
# 12067  2016S010144                 Eixample   Dissabte  Laboral  2016   12
# 12068  2016S010145           Horta-Guinardó  Divendres  Laboral  2016   12
# 12069  2016S010146                 Eixample   Dissabte  Laboral  2016   12
# 12070  2016S010147                 Eixample   Dimecres  Laboral  2016   12
# 12071  2016S010150           Horta-Guinardó   Dimecres  Laboral  2016   12
#
#        Dia Horario  Sexo  Edad TipoPersona TriajeVictima    C_UTM_X  \
# 0        1     Nit  Home    50   Conductor    Ferit lleu  428887.27
# 1        1     Nit  Home    47   Conductor    Ferit lleu  431987.02
# 2        1    Matí  Dona    27   Conductor    Ferit lleu  431615.63
# 3        1    Matí  Dona    40   Passatger    Ferit lleu  432466.78
# 4        1    Matí  Home    37   Conductor    Ferit lleu  432466.78
# 5        1    Matí  Home    61     Vianant    Ferit lleu  430384.25
# 6        1    Matí  Dona    31   Passatger    Ferit lleu  430197.72
# 7        1    Matí  Home    35   Conductor    Ferit lleu  430197.72
# 8        1   Tarda  Dona    35   Conductor    Ferit lleu  428117.94
# 9        1    Matí  Dona    91   Passatger    Ferit lleu  431588.98
# 10       1   Tarda  Home    29   Conductor    Ferit lleu  433205.10
# 11       1    Matí  Dona    23   Passatger    Ferit lleu  431727.67
# 12       1    Matí  Home    26   Conductor    Ferit lleu  431727.67
# 13       1   Tarda  Dona    57     Vianant    Ferit lleu  430079.43
# 14       1   Tarda  Home    50   Conductor    Ferit lleu  428117.94
# 15       1   Tarda  Home    18   Passatger    Ferit lleu  433317.96
# 16       1   Tarda  Home    49   Conductor    Ferit lleu  433317.96
# 17       1   Tarda  Dona    77   Passatger    Ferit lleu  432000.64
# 18       1   Tarda  Dona    15   Passatger    Ferit lleu  433348.96
# 19       1   Tarda  Dona    25   Conductor    Ferit lleu  433348.96
# 20       1   Tarda  Dona    26   Conductor    Ferit lleu  428947.81
# 21       1   Tarda  Dona    54   Passatger    Ferit lleu  433728.31
# 22       1     Nit  Home    51   Conductor    Ferit lleu  429371.43
# 23       3   Tarda  Dona    31   Passatger    Ferit lleu  427686.09
# 24       3   Tarda  Home    22   Conductor    Ferit lleu  427686.09
# 25       3   Tarda  Home    33   Conductor    Ferit lleu  427686.09
# 26       2    Matí  Dona    69     Vianant    Ferit lleu  429634.13
# 27       2    Matí  Dona    30   Conductor    Ferit lleu  427082.07
# 28       2    Matí  Dona    70   Conductor    Ferit lleu  427662.71
# 29       2    Matí  Home    25   Conductor    Ferit lleu  430424.49
# ...    ...     ...   ...   ...         ...           ...        ...
# 12042   30   Tarda  Dona    81   Conductor    Ferit lleu  429311.15
# 12043   30   Tarda  Home    23   Conductor    Ferit lleu  430741.88
# 12044   30   Tarda  Dona    25   Passatger    Ferit lleu  430741.88
# 12045   30   Tarda  Home    30   Conductor    Ferit lleu  430741.88
# 12046   30     Nit  Home    22   Conductor    Ferit lleu  433807.00
# 12047   30   Tarda  Dona    70   Passatger    Ferit lleu  430840.05
# 12048   31     Nit  Home    53   Conductor    Ferit lleu  430090.60
# 12049   30   Tarda  Home    30   Conductor    Ferit lleu  428105.57
# 12050   31     Nit  Home    29   Conductor    Ferit lleu  428106.71
# 12051   31     Nit  Home    53     Vianant    Ferit lleu  428106.71
# 12052   30    Matí  Home    27   Conductor    Ferit lleu  431329.55
# 12053   31     Nit  Home    61   Conductor    Ferit lleu  430787.59
# 12054   31    Matí  Home    50   Conductor    Ferit lleu  431413.87
# 12055   31    Matí  Home    43   Conductor    Ferit lleu  427340.27
# 12056   31    Matí  Home    37   Conductor    Ferit lleu  429392.53
# 12057   31    Matí  Home    45   Conductor    Ferit lleu  427755.77
# 12058   31    Matí  Home    30   Conductor    Ferit lleu  429266.68
# 12059   31   Tarda  Home    24   Conductor    Ferit lleu  430419.61
# 12060   30   Tarda  Home    57   Conductor    Ferit lleu  431472.06
# 12061   31   Tarda  Dona    81   Passatger    Ferit lleu  431665.97
# 12062   31   Tarda  Home    85   Conductor    Ferit lleu  431665.97
# 12063   31   Tarda  Home    28   Conductor    Ferit lleu  430520.22
# 12064   31   Tarda  Home    22   Conductor    Ferit lleu  432919.64
# 12065   31   Tarda  Home    41   Conductor    Ferit lleu  430578.06
# 12066   31   Tarda  Home    27   Conductor    Ferit lleu  428509.31
# 12067   31     Nit  Dona    29   Conductor    Ferit lleu  431448.70
# 12068   30   Tarda  Dona    77   Passatger    Ferit lleu  430722.23
# 12069   31     Nit  Dona    28   Conductor    Ferit lleu  429210.02
# 12070   28   Tarda  Dona    26   Conductor    Ferit lleu  430862.02
# 12071   21   Tarda  Home    13     Vianant    Ferit lleu  429956.23
#
#           C_UTM_Y       RangoEdad
# 0      4583659.10   Entre 41 y 60
# 1      4583282.61   Entre 41 y 60
# 2      4583971.63   Entre 21 y 40
# 3      4583327.27   Entre 21 y 40
# 4      4583327.27   Entre 21 y 40
# 5      4582001.59   Entre 61 y 80
# 6      4583116.33   Entre 21 y 40
# 7      4583116.33   Entre 21 y 40
# 8      4581559.38   Entre 21 y 40
# 9      4586110.37  Entre 81 a más
# 10     4582713.55   Entre 21 y 40
# 11     4583859.83   Entre 21 y 40
# 12     4583859.83   Entre 21 y 40
# 13     4582893.47   Entre 41 y 60
# 14     4581559.38   Entre 41 y 60
# 15     4585942.04    Entre 0 y 20
# 16     4585942.04   Entre 41 y 60
# 17     4583338.75   Entre 61 y 80
# 18     4585184.79    Entre 0 y 20
# 19     4585184.79   Entre 21 y 40
# 20     4582857.90   Entre 21 y 40
# 21     4584213.68   Entre 41 y 60
# 22     4583435.83   Entre 41 y 60
# 23     4580345.85   Entre 21 y 40
# 24     4580345.85   Entre 21 y 40
# 25     4580345.85   Entre 21 y 40
# 26     4579989.69   Entre 61 y 80
# 27     4582281.06   Entre 21 y 40
# 28     4581296.65   Entre 61 y 80
# 29     4584500.98   Entre 21 y 40
# ...           ...             ...
# 12042  4583333.46  Entre 81 a más
# 12043  4582396.64   Entre 21 y 40
# 12044  4582396.64   Entre 21 y 40
# 12045  4582396.64   Entre 21 y 40
# 12046  4585935.39   Entre 21 y 40
# 12047  4582248.15   Entre 61 y 80
# 12048  4587024.97   Entre 41 y 60
# 12049  4581888.51   Entre 21 y 40
# 12050  4586459.95   Entre 21 y 40
# 12051  4586459.95   Entre 41 y 60
# 12052  4586733.17   Entre 21 y 40
# 12053  4583482.29   Entre 61 y 80
# 12054  4583799.89   Entre 41 y 60
# 12055  4581935.11   Entre 41 y 60
# 12056  4586047.69   Entre 21 y 40
# 12057  4583047.82   Entre 41 y 60
# 12058  4582945.73   Entre 21 y 40
# 12059  4587099.61   Entre 21 y 40
# 12060  4588024.90   Entre 41 y 60
# 12061  4585139.54  Entre 81 a más
# 12062  4585139.54  Entre 81 a más
# 12063  4585219.99   Entre 21 y 40
# 12064  4587607.16   Entre 21 y 40
# 12065  4583903.49   Entre 41 y 60
# 12066  4585101.95   Entre 21 y 40
# 12067  4584339.40   Entre 21 y 40
# 12068  4585472.79   Entre 61 y 80
# 12069  4581242.99   Entre 21 y 40
# 12070  4584413.35   Entre 21 y 40
# 12071  4588050.33    Entre 0 y 20
#
# [24220 rows x 15 columns]

# %% [markdown]
# Castear Ano a Str

# %%
def camstr(fila):
    c = fila.Ano
    return str(c)

tmp2['Ano'] = tmp2.apply(camstr,axis=1)
tmp2.dtypes
# Out:
# NumExpediente     object
# Distrito          object
# DiaSemana         object
# TipoDia           object
# Ano               object
# Mes                int64
# Dia                int64
# Horario           object
# Sexo              object
# Edad               int64
# TipoPersona       object
# TriajeVictima     object
# C_UTM_X          float64
# C_UTM_Y          float64
# RangoEdad         object
# dtype: object

# %% [markdown]
# Castear Mes a Str

# %%
def camstr(fila):
    c = fila.Mes
    return str(c)

tmp2['Mes'] = tmp2.apply(camstr,axis=1)
tmp2.dtypes
# Out:
# NumExpediente     object
# Distrito          object
# DiaSemana         object
# TipoDia           object
# Ano               object
# Mes               object
# Dia                int64
# Horario           object
# Sexo              object
# Edad               int64
# TipoPersona       object
# TriajeVictima     object
# C_UTM_X          float64
# C_UTM_Y          float64
# RangoEdad         object
# dtype: object

# %% [markdown]
# Castear Dia a Str

# %%
def camstr(fila):
    return str(fila.Dia)

tmp2['Dia'] = tmp2.apply(camstr,axis=1)
tmp2.head()
# Out:
#      NumExpediente             Distrito DiaSemana  TipoDia   Ano Mes Dia  \
# 0  2017S000001      Sarrià-Sant Gervasi  Diumenge  Laboral  2017   1   1
# 1  2017S000002                 Eixample  Diumenge  Laboral  2017   1   1
# 2  2017S000004                 Eixample  Diumenge  Laboral  2017   1   1
# 3  2017S000005               Sant Martí  Diumenge  Laboral  2017   1   1
# 4  2017S000005               Sant Martí  Diumenge  Laboral  2017   1   1
#
#   Horario  Sexo  Edad TipoPersona TriajeVictima    C_UTM_X     C_UTM_Y  \
# 0     Nit  Home    50   Conductor    Ferit lleu  428887.27  4583659.10
# 1     Nit  Home    47   Conductor    Ferit lleu  431987.02  4583282.61
# 2    Matí  Dona    27   Conductor    Ferit lleu  431615.63  4583971.63
# 3    Matí  Dona    40   Passatger    Ferit lleu  432466.78  4583327.27
# 4    Matí  Home    37   Conductor    Ferit lleu  432466.78  4583327.27
#
#        RangoEdad
# 0  Entre 41 y 60
# 1  Entre 41 y 60
# 2  Entre 21 y 40
# 3  Entre 21 y 40
# 4  Entre 21 y 40

# %% [markdown]
# Unificar Dia, Mes y Ano

# %%
tmp3 = tmp2.copy()
tmp3['Fecha']= tmp3.Dia +'/'+ tmp3.Mes+'/'+ tmp3.Ano
tmp3.head()
# Out:
#      NumExpediente             Distrito DiaSemana  TipoDia   Ano Mes Dia  \
# 0  2017S000001      Sarrià-Sant Gervasi  Diumenge  Laboral  2017   1   1
# 1  2017S000002                 Eixample  Diumenge  Laboral  2017   1   1
# 2  2017S000004                 Eixample  Diumenge  Laboral  2017   1   1
# 3  2017S000005               Sant Martí  Diumenge  Laboral  2017   1   1
# 4  2017S000005               Sant Martí  Diumenge  Laboral  2017   1   1
#
#   Horario  Sexo  Edad TipoPersona TriajeVictima    C_UTM_X     C_UTM_Y  \
# 0     Nit  Home    50   Conductor    Ferit lleu  428887.27  4583659.10
# 1     Nit  Home    47   Conductor    Ferit lleu  431987.02  4583282.61
# 2    Matí  Dona    27   Conductor    Ferit lleu  431615.63  4583971.63
# 3    Matí  Dona    40   Passatger    Ferit lleu  432466.78  4583327.27
# 4    Matí  Home    37   Conductor    Ferit lleu  432466.78  4583327.27
#
#        RangoEdad     Fecha
# 0  Entre 41 y 60  1/1/2017
# 1  Entre 41 y 60  1/1/2017
# 2  Entre 21 y 40  1/1/2017
# 3  Entre 21 y 40  1/1/2017
# 4  Entre 21 y 40  1/1/2017

# %% [markdown]
# Castear la columna Fecha a datetime.strptime

# %%
def fecha(fila):
    a = datetime.strptime(fila.Fecha,'%d/%m/%Y')
    return a
    
tmp3['Fecha'] = tmp3.apply(fecha , axis=1)
tmp3.dtypes
# Out:
# NumExpediente            object
# Distrito                 object
# DiaSemana                object
# TipoDia                  object
# Ano                      object
# Mes                      object
# Dia                      object
# Horario                  object
# Sexo                     object
# Edad                      int64
# TipoPersona              object
# TriajeVictima            object
# C_UTM_X                 float64
# C_UTM_Y                 float64
# RangoEdad                object
# Fecha            datetime64[ns]
# dtype: object

# %% [markdown]
# Verificación de los cambios

# %%
tmp3[tmp3.Fecha != 0].shape
# Out:
# (24220, 16)

# %% [markdown]
# Verificación de la base

# %%
tmp3.head()
# Out:
#      NumExpediente             Distrito DiaSemana  TipoDia   Ano Mes Dia  \
# 0  2017S000001      Sarrià-Sant Gervasi  Diumenge  Laboral  2017   1   1
# 1  2017S000002                 Eixample  Diumenge  Laboral  2017   1   1
# 2  2017S000004                 Eixample  Diumenge  Laboral  2017   1   1
# 3  2017S000005               Sant Martí  Diumenge  Laboral  2017   1   1
# 4  2017S000005               Sant Martí  Diumenge  Laboral  2017   1   1
#
#   Horario  Sexo  Edad TipoPersona TriajeVictima    C_UTM_X     C_UTM_Y  \
# 0     Nit  Home    50   Conductor    Ferit lleu  428887.27  4583659.10
# 1     Nit  Home    47   Conductor    Ferit lleu  431987.02  4583282.61
# 2    Matí  Dona    27   Conductor    Ferit lleu  431615.63  4583971.63
# 3    Matí  Dona    40   Passatger    Ferit lleu  432466.78  4583327.27
# 4    Matí  Home    37   Conductor    Ferit lleu  432466.78  4583327.27
#
#        RangoEdad      Fecha
# 0  Entre 41 y 60 2017-01-01
# 1  Entre 41 y 60 2017-01-01
# 2  Entre 21 y 40 2017-01-01
# 3  Entre 21 y 40 2017-01-01
# 4  Entre 21 y 40 2017-01-01

# %% [markdown]
# Cambiar de Catalán a Español la columna DiaSemana

# %%
tmp4=tmp3.copy()

def rensem(a):
    if a.DiaSemana == 'Dijous':
        b='jueves'
    elif a.DiaSemana == 'Dilluns':
        b='lunes'
    elif a.DiaSemana == 'Dimarts':
        b='martes'
    elif a.DiaSemana == 'Dimecres':
        b='miercoles'
    elif a.DiaSemana == 'Dissabte':
        b='sabado'
    elif a.DiaSemana == 'Diumenge':
        b='domingo'
    elif a.DiaSemana == 'Divendres':
        b='viernes'
    return b
   
tmp4['DiaSemana'] = tmp4.apply(rensem, axis=1)       
tmp4.groupby('DiaSemana').count().iloc[:,1]
# Out:
# DiaSemana
# domingo      2076
# jueves       4002
# lunes        3547
# martes       3808
# miercoles    3859
# sabado       2842
# viernes      4086
# Name: Distrito, dtype: int64

# %%
tmp5=tmp4.copy()

def cambiosexo(a):
    if a.Sexo == 'Home':
        b='Hombre'
    elif a.Sexo == 'Dona':
        b='Mujer'
    elif a.Sexo == 'Desconegut':
        b='Desconocido'
    return b
   
tmp5['Sexo'] = tmp5.apply(cambiosexo, axis=1)       
tmp5.groupby('Sexo').count().iloc[:,1]
# Out:
# Sexo
# Desconocido      451
# Hombre         14469
# Mujer           9300
# Name: Distrito, dtype: int64

# %% [markdown]
# ## Gráfico

# %% [markdown]
# Gráfico de los accidentes dividido por las variables de Sexo y Rango Edad. En conclusión, los hombres entre la edad de 21 y 40 años están involucrados en mayor cantidad de accidentes vs. total de personas involucradas.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = 12, 12
sns.set_context('talk')

# %%
out = sns.countplot(x='Sexo', hue='RangoEdad', data=tmp5,palette='PuBuGn')

# %% [markdown]
# Gráfico de los accidentes dividido por las variables de Día de la semana y Rango Edad. En conclusión, el día de la semana de más accidentes es el Viernes y el rango de edad de las personas involucradas es entre 21 y 40 años.

# %%
out=sns.countplot(x='DiaSemana',hue='RangoEdad',data=tmp5,
                  hue_order=['Desconocido','Entre 0 y 20','Entre 21 y 40','Entre 41 y 60','Entre 61 y 80','Entre 81 a más'],
                  palette='PuBuGn', order=['lunes', 'martes', 'miercoles', 'jueves', 'viernes', 'sabado', 'domingo'])

# %% [markdown]
# ## Mapas

# %% [markdown]
# Importación de paquetes
#
# Nota: para el paquete utm se debe installar por medio de: pip install utm

# %%
import geopandas as gpd
import folium 
import utm

# %% [markdown]
# Trabajamos unicamente sobre la base de accidentes mortales

# %%
tmp8 = tmp5.copy()
M = tmp8[tmp8.TriajeVictima =='Mort']
len(M)
# Out:
# 31

# %% [markdown]
# Cambiamos las coordenadas UTM a latitud y longitud

# %%
M1 = M.copy()

M1['lalo'] = M1.apply(lambda f: utm.to_latlon(f.C_UTM_X, f.C_UTM_Y, 31 ,'T'), axis=1)
M1.head()
# Out:
#         NumExpediente        Distrito DiaSemana  TipoDia   Ano Mes Dia  \
# 124   2017S000104          Nou Barris    jueves  Laboral  2017   1   5
# 972   2017S000833      Horta-Guinardó    martes  Laboral  2017   1  31
# 2110  2017S001832      Horta-Guinardó     lunes  Laboral  2017   3   6
# 702   2016S000587         Sant Andreu    sabado  Laboral  2016   1  23
# 1434  2016S001203      Sants-Montjuïc    martes  Laboral  2016   2  16
#
#      Horario    Sexo  Edad TipoPersona TriajeVictima    C_UTM_X     C_UTM_Y  \
# 124     Matí  Hombre    89     Vianant          Mort  431819.04  4587014.09
# 972    Tarda   Mujer    72     Vianant          Mort  431417.32  4585293.23
# 2110    Matí   Mujer    29   Conductor          Mort  431016.83  4585753.22
# 702    Tarda  Hombre    23   Conductor          Mort  432502.93  4587850.91
# 1434    Matí  Hombre    40   Conductor          Mort  428177.58  4580971.35
#
#            RangoEdad      Fecha                                      lalo
# 124   Entre 81 a más 2017-01-05  (41.431800206630925, 2.1839563291351185)
# 972    Entre 61 y 80 2017-01-31    (41.41626682420349, 2.179343877514039)
# 2110   Entre 21 y 40 2017-03-06    (41.42037551158483, 2.174499652864413)
# 702    Entre 21 y 40 2016-01-23   (41.439394923447196, 2.192047417206565)
# 1434   Entre 21 y 40 2016-02-16    (41.37705834653117, 2.141094063542627)

# %% [markdown]
# Separar la tupla de lat_lon para utilizar la longitud y latitud que por el momento se identifica como object

# %%
M2=M1.copy()
M2['latitud'] = M2.apply(lambda f: f.lalo[0], axis=1)
M2['longitud'] = M2.apply(lambda f: f.lalo[1], axis=1)

M2.head(4)
# Out:
#         NumExpediente        Distrito DiaSemana  TipoDia   Ano Mes Dia  \
# 124   2017S000104          Nou Barris    jueves  Laboral  2017   1   5
# 972   2017S000833      Horta-Guinardó    martes  Laboral  2017   1  31
# 2110  2017S001832      Horta-Guinardó     lunes  Laboral  2017   3   6
# 702   2016S000587         Sant Andreu    sabado  Laboral  2016   1  23
#
#      Horario    Sexo  Edad TipoPersona TriajeVictima    C_UTM_X     C_UTM_Y  \
# 124     Matí  Hombre    89     Vianant          Mort  431819.04  4587014.09
# 972    Tarda   Mujer    72     Vianant          Mort  431417.32  4585293.23
# 2110    Matí   Mujer    29   Conductor          Mort  431016.83  4585753.22
# 702    Tarda  Hombre    23   Conductor          Mort  432502.93  4587850.91
#
#            RangoEdad      Fecha                                      lalo  \
# 124   Entre 81 a más 2017-01-05  (41.431800206630925, 2.1839563291351185)
# 972    Entre 61 y 80 2017-01-31    (41.41626682420349, 2.179343877514039)
# 2110   Entre 21 y 40 2017-03-06    (41.42037551158483, 2.174499652864413)
# 702    Entre 21 y 40 2016-01-23   (41.439394923447196, 2.192047417206565)
#
#         latitud  longitud
# 124   41.431800  2.183956
# 972   41.416267  2.179344
# 2110  41.420376  2.174500
# 702   41.439395  2.192047

# %% [markdown]
# En el mapa podemos ver donde sucedieron los accidentes mortales en Barcelona, que durante el 2016 y 2017 fueron un total de 30 accidentes con 31 personas involucradas

# %%
m = folium.Map(location=[41.4075163,2.1491085], zoom_start=12)
M2.apply(lambda f: folium.Marker([f.latitud , f.longitud]).add_to(m), axis=1 )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Calendar heatmaps

# %% [markdown]
# Se requiere primero instalar gmpolo por medio del comando pip install calmap

# %%
import calmap 
import numpy as np

# %% [markdown]
# Pasar la columna fecha a array

# %%
mfechas=np.array(tmp8.Fecha)
mfechas1 = pd.Series(1, index=mfechas)

# %%
out = calmap.calendarplot(mfechas1, monthticks=1, daylabels='LMMJVSD',
                    dayticks=[0,1, 2,3, 4,5,6], cmap='BuPu',
                    fillcolor='grey', linewidth=0,
                    fig_kws=dict(figsize=(18, 8)))

# %% [markdown]
# A diferencia de lo que se pueda pensar en la grafica anterior podemos observar que los dias en los cuales tenemos menos accidentes son los sabados y domingos, tanto en el 2016 como en el 2017. Asi mismo, tambien podemos ver que en ambos años el mes en que menos accidentes hay es Agosto. Y donde mas ccidentes tenemos indistintamente del dia fue en diciembre en el 2016 y en Noviembre en el 2017

# %% [markdown]
# ## Agregar ubicacion en base a latitud y longitud

# %% [markdown]
# Comenzar instalando geopy: pip install geopy

# %%
from geopy.geocoders import Nominatim

# %% [markdown]
# Nos quedamos con los datos que nos importan para buscar la direccion exacta de los accidente mortales segun la latitud y longitud

# %%
M3 = M2.iloc[:,[0,5,15,16]]
M3
# Out:
#          NumExpediente Mes      Fecha  \
# 124    2017S000104       1 2017-01-05
# 972    2017S000833       1 2017-01-31
# 2110   2017S001832       3 2017-03-06
# 702    2016S000587       1 2016-01-23
# 1434   2016S001203       2 2016-02-16
# 1590   2016S001336       2 2016-02-20
# 2169   2016S001812       3 2016-03-07
# 2456   2016S002058       3 2016-03-15
# 2473   2016S002076       3 2016-03-16
# 2564   2016S002160       3 2016-03-18
# 2570   2016S002166       3 2016-03-18
# 2571   2016S002167       3 2016-03-18
# 3704   2016S003122       4 2016-04-25
# 5148   2016S004368       6 2016-06-05
# 5844   2016S004943       6 2016-06-23
# 6678   2016S005652       7 2016-07-18
# 6876   2016S005825       7 2016-07-25
# 7416   2016S006296       8 2016-08-13
# 7457   2016S006322       8 2016-08-15
# 7462   2016S006322       8 2016-08-15
# 8012   2016S006777       9 2016-09-06
# 8073   2016S006829       9 2016-09-08
# 8174   2016S006910       9 2016-09-12
# 8204   2016S006933       9 2016-09-13
# 8386   2016S007066       9 2016-09-17
# 8530   2016S007181       9 2016-09-21
# 10665  2016S008971      11 2016-11-22
# 10777  2016S009061      11 2016-11-25
# 10990  2016S009258      12 2016-12-01
# 11957  2016S010049      12 2016-12-28
# 12014  2016S010094      12 2016-12-29
#
#                                            lalo
# 124    (41.431800206630925, 2.1839563291351185)
# 972      (41.41626682420349, 2.179343877514039)
# 2110     (41.42037551158483, 2.174499652864413)
# 702     (41.439394923447196, 2.192047417206565)
# 1434     (41.37705834653117, 2.141094063542627)
# 1590     (41.39365549700966, 2.130470393114779)
# 2169    (41.40013165910244, 2.1543200804885068)
# 2456    (41.40533073950313, 2.1286867150354487)
# 2473   (41.382810453125295, 2.1586377460875172)
# 2564      (41.38305190618905, 2.18275348327388)
# 2570    (41.42219269803267, 2.1781133866043403)
# 2571    (41.398397186203105, 2.162980961957345)
# 3704      (41.40031932763254, 2.14752714728173)
# 5148    (41.40441579804327, 2.1385242000487406)
# 5844       (41.4033918407633, 2.13722760658061)
# 6678     (41.45029952997453, 2.189031283352663)
# 6876   (41.383705408267495, 2.1642572688117108)
# 7416     (41.39404127354497, 2.170721435221385)
# 7457     (41.44086247805486, 2.167522547978913)
# 7462     (41.44086247805486, 2.167522547978913)
# 8012     (41.42041053685711, 2.173255880122737)
# 8073    (41.35073700021592, 2.1459029665074594)
# 8174     (41.38039539827726, 2.139519731692516)
# 8204      (41.40698774043298, 2.14495324277445)
# 8386    (41.376327136738105, 2.175842298969506)
# 8530   (41.386788556957434, 2.1237871594305497)
# 10665   (41.38879132286344, 2.1245023148151634)
# 10777    (41.3907407037002, 2.1324792347728074)
# 10990    (41.41495442782368, 2.141244974853275)
# 11957    (41.3673532875842, 2.1367016681370643)
# 12014   (41.40412464312407, 2.1874010321805026)

# %% [markdown]
# Hacemos una prueba para sacar la direccion del accidente en base a la latitud y longitud

# %%
geolocator = Nominatim(user_agent="xxx")
geo = geolocator.reverse("41.431800,2.183956")
datos = geo.address
datos
# Out:
# '410, Avinguda Meridiana, Sant Andreu de Palomar, Sant Andreu, Barcelona, BCN, CAT, 08027, España'

# %% [markdown]
# Ahora sacamos unicamente el distrito

# %%
datos.split(',')[3]
# Out:
# ' Sant Andreu'

# %% [markdown]
# Creamos una nueva columna llamada distrito y aplicamos las formulas antes vistas para conseguir el distrito en el que ocurrio el accidente segun la latitud y longitud

# %%
M3['Distrito']=M3.apply(lambda fila: geolocator.reverse(fila.lalo).address.split(',')[3],axis=1 )
M3
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          NumExpediente Mes      Fecha  \
# 124    2017S000104       1 2017-01-05
# 972    2017S000833       1 2017-01-31
# 2110   2017S001832       3 2017-03-06
# 702    2016S000587       1 2016-01-23
# 1434   2016S001203       2 2016-02-16
# 1590   2016S001336       2 2016-02-20
# 2169   2016S001812       3 2016-03-07
# 2456   2016S002058       3 2016-03-15
# 2473   2016S002076       3 2016-03-16
# 2564   2016S002160       3 2016-03-18
# 2570   2016S002166       3 2016-03-18
# 2571   2016S002167       3 2016-03-18
# 3704   2016S003122       4 2016-04-25
# 5148   2016S004368       6 2016-06-05
# 5844   2016S004943       6 2016-06-23
# 6678   2016S005652       7 2016-07-18
# 6876   2016S005825       7 2016-07-25
# 7416   2016S006296       8 2016-08-13
# 7457   2016S006322       8 2016-08-15
# 7462   2016S006322       8 2016-08-15
# 8012   2016S006777       9 2016-09-06
# 8073   2016S006829       9 2016-09-08
# 8174   2016S006910       9 2016-09-12
# 8204   2016S006933       9 2016-09-13
# 8386   2016S007066       9 2016-09-17
# 8530   2016S007181       9 2016-09-21
# 10665  2016S008971      11 2016-11-22
# 10777  2016S009061      11 2016-11-25
# 10990  2016S009258      12 2016-12-01
# 11957  2016S010049      12 2016-12-28
# 12014  2016S010094      12 2016-12-29
#
#                                            lalo                     Distrito
# 124    (41.431800206630925, 2.1839563291351185)                  Sant Andreu
# 972      (41.41626682420349, 2.179343877514039)                   Sant Martí
# 2110     (41.42037551158483, 2.174499652864413)               Horta-Guinardó
# 702     (41.439394923447196, 2.192047417206565)                  Sant Andreu
# 1434     (41.37705834653117, 2.141094063542627)               Sants-Montjuïc
# 1590     (41.39365549700966, 2.130470393114779)        Sarrià - Sant Gervasi
# 2169    (41.40013165910244, 2.1543200804885068)                       Gràcia
# 2456    (41.40533073950313, 2.1286867150354487)   Sant Gervasi - la Bonanova
# 2473   (41.382810453125295, 2.1586377460875172)                     Eixample
# 2564      (41.38305190618905, 2.18275348327388)                    Sant Pere
# 2570    (41.42219269803267, 2.1781133866043403)               Horta-Guinardó
# 2571    (41.398397186203105, 2.162980961957345)                     Eixample
# 3704      (41.40031932763254, 2.14752714728173)        Sarrià - Sant Gervasi
# 5148    (41.40441579804327, 2.1385242000487406)        Sarrià - Sant Gervasi
# 5844       (41.4033918407633, 2.13722760658061)                     Eixample
# 6678     (41.45029952997453, 2.189031283352663)                  Sant Andreu
# 6876   (41.383705408267495, 2.1642572688117108)                 Ciutat Vella
# 7416     (41.39404127354497, 2.170721435221385)   Santa Caterina i la Ribera
# 7457     (41.44086247805486, 2.167522547978913)                 la Guineueta
# 7462     (41.44086247805486, 2.167522547978913)                 la Guineueta
# 8012     (41.42041053685711, 2.173255880122737)               Horta-Guinardó
# 8073    (41.35073700021592, 2.1459029665074594)               Sants-Montjuïc
# 8174     (41.38039539827726, 2.139519731692516)               Sants-Montjuïc
# 8204      (41.40698774043298, 2.14495324277445)                       Gràcia
# 8386    (41.376327136738105, 2.175842298969506)                 Ciutat Vella
# 8530   (41.386788556957434, 2.1237871594305497)                     Eixample
# 10665   (41.38879132286344, 2.1245023148151634)                    les Corts
# 10777    (41.3907407037002, 2.1324792347728074)                    Barcelona
# 10990    (41.41495442782368, 2.141244974853275)    Vallcarca i els Penitents
# 11957    (41.3673532875842, 2.1367016681370643)                    Barcelona
# 12014   (41.40412464312407, 2.1874010321805026)                     Eixample

# %% [markdown]
# En el siguiente cuadro podemos observar que en el distrito en que tuvimos más accidentes mortales fue en 'Eixample'

# %%
M4 = M3.copy()

M4.groupby('Distrito').count().iloc[:,1].sort_values(ascending=False)
# Out:
# Distrito
#  Eixample                      5
#  Sarrià - Sant Gervasi         3
#  Sants-Montjuïc                3
#  Sant Andreu                   3
#  Horta-Guinardó                3
#  la Guineueta                  2
#  Gràcia                        2
#  Ciutat Vella                  2
#  Barcelona                     2
#  les Corts                     1
#  Vallcarca i els Penitents     1
#  Santa Caterina i la Ribera    1
#  Sant Pere                     1
#  Sant Martí                    1
#  Sant Gervasi - la Bonanova    1
# Name: Mes, dtype: int64
